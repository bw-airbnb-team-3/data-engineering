# %%
import numpy as np
import gzip
import pandas as pd
#import pandas_profiling
#!pip install bayesian-optimization
from bayes_opt import BayesianOptimization
import matplotlib as mpb

# %%
detailed_listing = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/data/listings.csv.gz'
summary_listing = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/visualisations/listings.csv'

# %%
det_list = pd.read_csv(detailed_listing, compression='gzip', error_bad_lines=False, warn_bad_lines=False)

print(det_list.shape)
det_list.head()
# Out:
# (40125, 106)
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20191205175409   2019-12-06
# 1   344   https://www.airbnb.com/rooms/344  20191205175409   2019-12-06
# 2  2708  https://www.airbnb.com/rooms/2708  20191205175409   2019-12-06
# 3  2732  https://www.airbnb.com/rooms/2732  20191205175409   2019-12-06
# 4  2864  https://www.airbnb.com/rooms/2864  20191205175409   2019-12-07
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1                  Family perfect;Pool;Near Studios!
# 2  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3                              Zen Life at the Beach
# 4  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
# 1  This home is perfect for families; aspiring ch...                none
# 2  Our best memory foam pillows you'll ever sleep...                none
# 3  This is a three story townhouse with the follo...                none
# 4  Centrally located.... Furnished with 42 inch S...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Quiet-yet-close to all the fun in LA! Hollywoo...  ...                t
# 2  We are minutes away from the Mentor Language I...  ...                t
# 3                                                NaN  ...                f
# 4  What makes the neighborhood unique is that the...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02
# 1                                            0               0.19
# 2                                            0               0.33
# 3                                            0               0.19
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
summary_list = pd.read_csv(summary_listing, error_bad_lines=False, warn_bad_lines=False )

print(summary_list.shape)
summary_list.head()
# Out:
# (40125, 16)
#      id                                               name  host_id  \
# 0   109  Amazing bright elegant condo park front *UPGRA...      521
# 1   344                  Family perfect;Pool;Near Studios!      767
# 2  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     3008
# 3  2732                              Zen Life at the Beach     3041
# 4  2864  *Upscale Professional Home with Beautiful Studio*     3207
#
#         host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0           Paolo         Other Cities   Culver City  33.98209 -118.38494
# 1         Melissa         Other Cities       Burbank  34.16562 -118.33458
# 2           Chas.  City of Los Angeles     Hollywood  34.09768 -118.34602
# 3  Yoga Priestess         Other Cities  Santa Monica  34.00475 -118.48127
# 4       Bernadine         Other Cities    Bellflower  33.87619 -118.11397
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    122              30                  2  2016-05-15
# 1  Entire home/apt    168               2                  8  2019-10-19
# 2     Private room     79              30                 22  2019-08-31
# 3     Private room    140               1                 20  2019-10-03
# 4  Entire home/apt     80               2                  0         NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.02                               1               248
# 1               0.19                               1                62
# 2               0.33                               2               252
# 3               0.19                               2               344
# 4                NaN                               1                 0

# %%
calendar_url = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/data/calendar.csv.gz'

# %%
calendar_df = pd.read_csv(calendar_url, compression='gzip', warn_bad_lines=False, error_bad_lines=False)

print(calendar_df.shape)
calendar_df.head()
# Out:
# (14670849, 7)
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       46858  2019-12-06         f  $300.00        $300.00             3.0
# 1      130915  2019-12-06         f   $90.00         $90.00             1.0
# 2      130915  2019-12-07         f   $90.00         $90.00             1.0
# 3      130915  2019-12-08         f   $90.00         $90.00             1.0
# 4      130915  2019-12-09         f   $90.00         $90.00             1.0
#
#    maximum_nights
# 0            30.0
# 1           730.0
# 2           730.0
# 3           730.0
# 4           730.0

# %%
calendar_df['date'] = pd.to_datetime(calendar_df['date'])
calendar_df['year'] = calendar_df['date'].dt.year
calendar_df['month'] = calendar_df['date'].dt.month
calendar_df['day'] = calendar_df['date'].dt.day
calendar_df = calendar_df.drop(columns='date')
calendar_df['available'] = calendar_df['available'].astype(str)
calendar_df['price'] = calendar_df['price'].replace('$','')
calendar_df['adjusted_price'] = calendar_df['adjusted_price'].str[1:]
# Take care of NAs so this code can run
calendar_df['minimum_nights'].fillna(calendar_df['minimum_nights'].mode()[0], inplace=True)
calendar_df['minimum_nights'] = calendar_df['minimum_nights'].astype(int)
calendar_df['maximum_nights'].fillna(calendar_df['maximum_nights'].mode()[0], inplace=True)
calendar_df['maximum_nights'] = calendar_df['maximum_nights'].astype(int)
calendar_df['price'] = calendar_df['price'].str[1:]
calendar_df.head()
# Out:
#    listing_id available   price adjusted_price  minimum_nights  \
# 0       46858         f  300.00         300.00               3
# 1      130915         f   90.00          90.00               1
# 2      130915         f   90.00          90.00               1
# 3      130915         f   90.00          90.00               1
# 4      130915         f   90.00          90.00               1
#
#    maximum_nights  year  month  day
# 0              30  2019     12    6
# 1             730  2019     12    6
# 2             730  2019     12    7
# 3             730  2019     12    8
# 4             730  2019     12    9

# %%
list(summary_list.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
list(det_list.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
#pandas_profiling.ProfileReport(det_list)

# %%
det_list.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20191205175409   2019-12-06
# 1   344   https://www.airbnb.com/rooms/344  20191205175409   2019-12-06
# 2  2708  https://www.airbnb.com/rooms/2708  20191205175409   2019-12-06
# 3  2732  https://www.airbnb.com/rooms/2732  20191205175409   2019-12-06
# 4  2864  https://www.airbnb.com/rooms/2864  20191205175409   2019-12-07
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1                  Family perfect;Pool;Near Studios!
# 2  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3                              Zen Life at the Beach
# 4  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
# 1  This home is perfect for families; aspiring ch...                none
# 2  Our best memory foam pillows you'll ever sleep...                none
# 3  This is a three story townhouse with the follo...                none
# 4  Centrally located.... Furnished with 42 inch S...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Quiet-yet-close to all the fun in LA! Hollywoo...  ...                t
# 2  We are minutes away from the Mentor Language I...  ...                t
# 3                                                NaN  ...                f
# 4  What makes the neighborhood unique is that the...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02
# 1                                            0               0.19
# 2                                            0               0.33
# 3                                            0               0.19
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
columns = ['price', 'beds', 'bedrooms', 'bathrooms', 'zipcode', 'neighbourhood', 
           'property_type', 'room_type', 'accommodates', 'guests_included',
           'minimum_nights', 'instant_bookable']

train = det_list[columns]

train.head()
# Out:
#      price  beds  bedrooms  bathrooms zipcode neighbourhood property_type  \
# 0  $122.00   3.0       2.0        2.0   90230   Culver City   Condominium
# 1  $168.00   3.0       3.0        1.0   91505       Burbank         House
# 2   $79.00   1.0       1.0        1.5   90046     Hollywood     Apartment
# 3  $140.00   1.0       1.0        1.0   90405  Santa Monica     Apartment
# 4   $80.00   1.0       1.0        1.0   90706    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  minimum_nights  \
# 0  Entire home/apt             6                3              30
# 1  Entire home/apt             6                6               2
# 2     Private room             1                1              30
# 3     Private room             1                1               1
# 4  Entire home/apt             2                1               2
#
#   instant_bookable
# 0                f
# 1                t
# 2                t
# 3                f
# 4                f

# %%
train['price'] = train['price'].str.replace('$','')
train['price'] = train['price'].str.replace(',','').astype('float')

train['beds'] = train['beds'].fillna(train['beds'].mode()[0])
train['beds'] = train['beds'].astype(int)

train['zipcode'] = train['zipcode'].str.strip()
train['zipcode'] = np.where(train['zipcode'].str.contains('ca', case = False), '', train['zipcode'])
train['zipcode'] = train['zipcode'].str.replace(' ', '')
train['zipcode'] = train['zipcode'].str.replace('139SValenciaAve,Glendora.', '')
train['zipcode'] = train['zipcode'].str[:5]
train['zipcode'] = train['zipcode'].replace('',np.nan)
train['zipcode'] = train['zipcode'].astype('float')

train['instant_bookable'] = np.where(train['instant_bookable'].str.contains('t'), 1, 0)
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
train.head()
# Out:
#    price  beds  bedrooms  bathrooms  zipcode neighbourhood property_type  \
# 0  122.0     3       2.0        2.0  90230.0   Culver City   Condominium
# 1  168.0     3       3.0        1.0  91505.0       Burbank         House
# 2   79.0     1       1.0        1.5  90046.0     Hollywood     Apartment
# 3  140.0     1       1.0        1.0  90405.0  Santa Monica     Apartment
# 4   80.0     1       1.0        1.0  90706.0    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  minimum_nights  \
# 0  Entire home/apt             6                3              30
# 1  Entire home/apt             6                6               2
# 2     Private room             1                1              30
# 3     Private room             1                1               1
# 4  Entire home/apt             2                1               2
#
#    instant_bookable
# 0                 0
# 1                 1
# 2                 1
# 3                 0
# 4                 0

# %%
train.dtypes
# Out:
# price               float64
# beds                  int32
# bedrooms            float64
# bathrooms           float64
# zipcode             float64
# neighbourhood        object
# property_type        object
# room_type            object
# accommodates          int64
# guests_included       int64
# minimum_nights        int64
# instant_bookable      int32
# dtype: object

# %%
import xgboost as xgb
from sklearn.compose import ColumnTransformer
import category_encoders as ce

# %%
columns = ['price', 'beds', 'bedrooms', 'bathrooms', 'zipcode', 'neighbourhood', 
           'property_type', 'room_type', 'accommodates', 'guests_included',
           'minimum_nights', 'instant_bookable']

train = det_list[columns]

train.head()
# Out:
#      price  beds  bedrooms  bathrooms zipcode neighbourhood property_type  \
# 0  $122.00   3.0       2.0        2.0   90230   Culver City   Condominium
# 1  $168.00   3.0       3.0        1.0   91505       Burbank         House
# 2   $79.00   1.0       1.0        1.5   90046     Hollywood     Apartment
# 3  $140.00   1.0       1.0        1.0   90405  Santa Monica     Apartment
# 4   $80.00   1.0       1.0        1.0   90706    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  minimum_nights  \
# 0  Entire home/apt             6                3              30
# 1  Entire home/apt             6                6               2
# 2     Private room             1                1              30
# 3     Private room             1                1               1
# 4  Entire home/apt             2                1               2
#
#   instant_bookable
# 0                f
# 1                t
# 2                t
# 3                f
# 4                f

# %%
train['price'] = train['price'].str.replace('$','')
train['price'] = train['price'].str.replace(',','').astype('float')

train['beds'] = train['beds'].fillna(train['beds'].mode()[0])
#train['beds'].fillna(train['beds'].mode()[0], inplace=True)
train['beds'] = train['beds'].astype(int)

train['zipcode'] = train['zipcode'].str.strip()
train['zipcode'] = np.where(train['zipcode'].str.contains('ca', case = False), '', train['zipcode'])
train['zipcode'] = train['zipcode'].str.replace(' ', '')
train['zipcode'] = train['zipcode'].str.replace('139SValenciaAve,Glendora.', '')
train['zipcode'] = train['zipcode'].str[:5]
train['zipcode'] = train['zipcode'].replace('',np.nan)
train['zipcode'] = train['zipcode'].astype(str)

train['instant_bookable'] = np.where(train['instant_bookable'].str.contains('t'), 1, 0)
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
train.dtypes
# Out:
# price               float64
# beds                  int32
# bedrooms            float64
# bathrooms           float64
# zipcode              object
# neighbourhood        object
# property_type        object
# room_type            object
# accommodates          int64
# guests_included       int64
# minimum_nights        int64
# instant_bookable      int32
# dtype: object

# %%
##next will do a linear regression model for a baseline

# %%
# Features we want
categorical_features = ['zipcode','neighbourhood','property_type','room_type']
numeric_features = ['price', 'beds', 'bedrooms', 'bathrooms','accommodates','guests_included','minimum_nights','instant_bookable']

# %%
#categorical_counts = train.select_dtypes(exclude='number').nunique().sort_values()
categorical_counts = []
categorical_counts.append(train[categorical_features].nunique().sort_values())
high_cardi_cols = []
low_cardi_cols = []
for i in categorical_features:
    if train[i].nunique() > 150:
        high_cardi_cols.append(i)
    else:
        low_cardi_cols.append(i)

# %%
print(categorical_counts, high_cardi_cols, low_cardi_cols)
# Out:
# [room_type          4
# property_type     44
# neighbourhood    165
# zipcode          295
# dtype: int64] ['zipcode', 'neighbourhood'] ['property_type', 'room_type']

# %%
ct = ColumnTransformer([("oe", ce.OrdinalEncoder(), high_cardi_cols),
                        ("ohe", ce.OneHotEncoder(use_cat_names=True), low_cardi_cols)])

# %%
# We'll impute missing values using the median for numeric columns and the most
# common value for string columns.

from sklearn.base import TransformerMixin
class DataFrameImputer(TransformerMixin):
    def fit(self, X, y=None):
        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].median() for c in X],
            index=X.columns)
        return self
    def transform(self, X, y=None):
        return X.fillna(self.fill)

train = DataFrameImputer().fit_transform(train)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
for feature in categorical_features:
    train[feature] = label_encoder.fit_transform(train[feature])

# %%
train.head()
# Out:
#    price  beds  bedrooms  bathrooms  zipcode  neighbourhood  property_type  \
# 0  122.0     3       2.0        2.0       77             29             15
# 1  168.0     3       3.0        1.0      229             19             25
# 2   79.0     1       1.0        1.5       50             59              1
# 3  140.0     1       1.0        1.0      113            118              1
# 4   80.0     1       1.0        1.0      133             14              1
#
#    room_type  accommodates  guests_included  minimum_nights  instant_bookable
# 0          0             6                3              30                 0
# 1          0             6                6               2                 1
# 2          2             1                1              30                 1
# 3          2             1                1               1                 0
# 4          0             2                1               2                 0

# %%
features = numeric_features + categorical_features
target = 'price'
train_features = train[features]

# %%
train_labels = train_features['price']
train_features = train_features.drop(columns=['price'])

# %%
X_train = train_features
y_train = train_labels

X_train.shape, y_train.shape
# Out:
# ((40125, 11), (40125,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size = 0.80, 
                                                  test_size = 0.20, random_state=42)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((32100, 11), (8025, 11), (32100,), (8025,))

# %%
from xgboost import XGBRegressor


eval_set = [(X_train, y_train), 
            (X_val, y_val)]

model = XGBRegressor(n_estimators=1000, n_jobs=-1)
model.fit(X_train, y_train, eval_set=eval_set, eval_metric='rmse', 
          early_stopping_rounds=100)
# Out:
# [11:33:51] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:658.311	validation_1-rmse:707.754
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [1]	validation_0-rmse:635.297	validation_1-rmse:688.316
# [2]	validation_0-rmse:615.691	validation_1-rmse:672.534
# [3]	validation_0-rmse:597.62	validation_1-rmse:658.274
# [4]	validation_0-rmse:581.556	validation_1-rmse:641.798
# [5]	validation_0-rmse:567.943	validation_1-rmse:627.606
# [6]	validation_0-rmse:556.12	validation_1-rmse:615.794
# [7]	validation_0-rmse:546.557	validation_1-rmse:608.996
# [8]	validation_0-rmse:537.854	validation_1-rmse:600.314
# [9]	validation_0-rmse:530.433	validation_1-rmse:592.476
# [10]	validation_0-rmse:523.564	validation_1-rmse:585.213
# [11]	validation_0-rmse:517.989	validation_1-rmse:579.602
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [12]	validation_0-rmse:513.049	validation_1-rmse:574.469
# [13]	validation_0-rmse:508.937	validation_1-rmse:570.304
# [14]	validation_0-rmse:505.133	validation_1-rmse:566.319
# [15]	validation_0-rmse:502.052	validation_1-rmse:562.895
# [16]	validation_0-rmse:498.863	validation_1-rmse:561.659
# [17]	validation_0-rmse:495.93	validation_1-rmse:559.975
# [18]	validation_0-rmse:493.5	validation_1-rmse:559.281
# [19]	validation_0-rmse:491.255	validation_1-rmse:558.102
# [20]	validation_0-rmse:488.782	validation_1-rmse:555.145
# [21]	validation_0-rmse:487.062	validation_1-rmse:554.667
# [22]	validation_0-rmse:485.51	validation_1-rmse:553.886
# [23]	validation_0-rmse:483.898	validation_1-rmse:552.401
# [24]	validation_0-rmse:482.573	validation_1-rmse:552.263
# [25]	validation_0-rmse:481.265	validation_1-rmse:551.253
# [26]	validation_0-rmse:480.161	validation_1-rmse:550.736
# [27]	validation_0-rmse:478.606	validation_1-rmse:549.893
# [28]	validation_0-rmse:477.708	validation_1-rmse:549.934
# [29]	validation_0-rmse:476.47	validation_1-rmse:549.137
# [30]	validation_0-rmse:475.276	validation_1-rmse:548.605
# [31]	validation_0-rmse:474.16	validation_1-rmse:547.869
# [32]	validation_0-rmse:473.123	validation_1-rmse:547.148
# [33]	validation_0-rmse:471.541	validation_1-rmse:547.434
# [34]	validation_0-rmse:470.584	validation_1-rmse:545.298
# [35]	validation_0-rmse:469.948	validation_1-rmse:544.62
# [36]	validation_0-rmse:468.973	validation_1-rmse:544.189
# [37]	validation_0-rmse:468.256	validation_1-rmse:543.577
# [38]	validation_0-rmse:467.819	validation_1-rmse:543.402
# [39]	validation_0-rmse:466.993	validation_1-rmse:542.956
# [40]	validation_0-rmse:465.917	validation_1-rmse:542.848
# [41]	validation_0-rmse:464.963	validation_1-rmse:542.821
# [42]	validation_0-rmse:464.555	validation_1-rmse:542.555
# [43]	validation_0-rmse:463.837	validation_1-rmse:540.615
# [44]	validation_0-rmse:462.711	validation_1-rmse:540.509
# [45]	validation_0-rmse:462.109	validation_1-rmse:540.125
# [46]	validation_0-rmse:461.746	validation_1-rmse:540.265
# [47]	validation_0-rmse:461.463	validation_1-rmse:540.066
# [48]	validation_0-rmse:460.621	validation_1-rmse:539.651
# [49]	validation_0-rmse:460.335	validation_1-rmse:539.769
# [50]	validation_0-rmse:459.599	validation_1-rmse:539.599
# [51]	validation_0-rmse:459.192	validation_1-rmse:539.265
# [52]	validation_0-rmse:458.891	validation_1-rmse:538.757
# [53]	validation_0-rmse:458.717	validation_1-rmse:538.525
# [54]	validation_0-rmse:457.942	validation_1-rmse:537.973
# [55]	validation_0-rmse:457.751	validation_1-rmse:538.074
# [56]	validation_0-rmse:457.532	validation_1-rmse:538.043
# [57]	validation_0-rmse:457.224	validation_1-rmse:537.795
# [58]	validation_0-rmse:456.429	validation_1-rmse:537.699
# [59]	validation_0-rmse:456.19	validation_1-rmse:537.309
# [60]	validation_0-rmse:455.697	validation_1-rmse:536.991
# [61]	validation_0-rmse:455.623	validation_1-rmse:536.969
# [62]	validation_0-rmse:455.528	validation_1-rmse:537.004
# [63]	validation_0-rmse:455.224	validation_1-rmse:536.748
# [64]	validation_0-rmse:454.673	validation_1-rmse:536.439
# [65]	validation_0-rmse:454.384	validation_1-rmse:536.202
# [66]	validation_0-rmse:453.88	validation_1-rmse:536.143
# [67]	validation_0-rmse:453.121	validation_1-rmse:535.618
# [68]	validation_0-rmse:452.197	validation_1-rmse:534.317
# [69]	validation_0-rmse:450.621	validation_1-rmse:533.519
# [70]	validation_0-rmse:450.042	validation_1-rmse:533.565
# [71]	validation_0-rmse:449.875	validation_1-rmse:533.156
# [72]	validation_0-rmse:449.561	validation_1-rmse:532.897
# [73]	validation_0-rmse:449.429	validation_1-rmse:532.616
# [74]	validation_0-rmse:448.02	validation_1-rmse:531.546
# [75]	validation_0-rmse:447.869	validation_1-rmse:531.899
# [76]	validation_0-rmse:447.65	validation_1-rmse:531.727
# [77]	validation_0-rmse:447.041	validation_1-rmse:531.385
# [78]	validation_0-rmse:446.307	validation_1-rmse:530.447
# [79]	validation_0-rmse:445.221	validation_1-rmse:529.758
# [80]	validation_0-rmse:445.034	validation_1-rmse:529.681
# [81]	validation_0-rmse:443.837	validation_1-rmse:528.204
# [82]	validation_0-rmse:442.912	validation_1-rmse:527.59
# [83]	validation_0-rmse:442.78	validation_1-rmse:527.388
# [84]	validation_0-rmse:442.65	validation_1-rmse:527.336
# [85]	validation_0-rmse:441.844	validation_1-rmse:526.346
# [86]	validation_0-rmse:441.309	validation_1-rmse:525.201
# [87]	validation_0-rmse:441.079	validation_1-rmse:525.111
# [88]	validation_0-rmse:440.955	validation_1-rmse:524.851
# [89]	validation_0-rmse:440.163	validation_1-rmse:524.377
# [90]	validation_0-rmse:439.739	validation_1-rmse:523.408
# [91]	validation_0-rmse:439.599	validation_1-rmse:523.381
# [92]	validation_0-rmse:439.516	validation_1-rmse:523.383
# [93]	validation_0-rmse:439.425	validation_1-rmse:523.489
# [94]	validation_0-rmse:439.296	validation_1-rmse:523.545
# [95]	validation_0-rmse:439.052	validation_1-rmse:523.233
# [96]	validation_0-rmse:438.39	validation_1-rmse:522.326
# [97]	validation_0-rmse:438.305	validation_1-rmse:522.002
# [98]	validation_0-rmse:438.192	validation_1-rmse:521.921
# [99]	validation_0-rmse:438.08	validation_1-rmse:522.125
# [100]	validation_0-rmse:437.934	validation_1-rmse:521.966
# [101]	validation_0-rmse:437.873	validation_1-rmse:522.026
# [102]	validation_0-rmse:437.536	validation_1-rmse:521.225
# [103]	validation_0-rmse:436.966	validation_1-rmse:520.719
# [104]	validation_0-rmse:436.671	validation_1-rmse:520.456
# [105]	validation_0-rmse:436.107	validation_1-rmse:520.315
# [106]	validation_0-rmse:435.912	validation_1-rmse:520.147
# [107]	validation_0-rmse:435.84	validation_1-rmse:519.893
# [108]	validation_0-rmse:435.727	validation_1-rmse:519.74
# [109]	validation_0-rmse:435.304	validation_1-rmse:519.271
# [110]	validation_0-rmse:435.177	validation_1-rmse:519.211
# [111]	validation_0-rmse:434.779	validation_1-rmse:518.904
# [112]	validation_0-rmse:434.254	validation_1-rmse:518.119
# [113]	validation_0-rmse:433.69	validation_1-rmse:517.836
# [114]	validation_0-rmse:433.389	validation_1-rmse:517.56
# [115]	validation_0-rmse:433.293	validation_1-rmse:517.444
# [116]	validation_0-rmse:433.174	validation_1-rmse:517.105
# [117]	validation_0-rmse:432.715	validation_1-rmse:516.77
# [118]	validation_0-rmse:432.622	validation_1-rmse:516.744
# [119]	validation_0-rmse:432.521	validation_1-rmse:516.756
# [120]	validation_0-rmse:432.445	validation_1-rmse:516.741
# [121]	validation_0-rmse:432.238	validation_1-rmse:516.715
# [122]	validation_0-rmse:431.853	validation_1-rmse:516.001
# [123]	validation_0-rmse:431.808	validation_1-rmse:515.972
# [124]	validation_0-rmse:431.714	validation_1-rmse:515.863
# [125]	validation_0-rmse:431.448	validation_1-rmse:515.482
# [126]	validation_0-rmse:430.498	validation_1-rmse:515.101
# [127]	validation_0-rmse:430.034	validation_1-rmse:514.852
# [128]	validation_0-rmse:429.957	validation_1-rmse:514.763
# [129]	validation_0-rmse:429.859	validation_1-rmse:514.737
# [130]	validation_0-rmse:429.774	validation_1-rmse:514.734
# [131]	validation_0-rmse:429.708	validation_1-rmse:514.698
# [132]	validation_0-rmse:429.235	validation_1-rmse:515.04
# [133]	validation_0-rmse:429.208	validation_1-rmse:514.974
# [134]	validation_0-rmse:428.928	validation_1-rmse:514.691
# [135]	validation_0-rmse:428.787	validation_1-rmse:514.663
# [136]	validation_0-rmse:428.77	validation_1-rmse:514.606
# [137]	validation_0-rmse:428.543	validation_1-rmse:514.566
# [138]	validation_0-rmse:428.502	validation_1-rmse:514.57
# [139]	validation_0-rmse:428.223	validation_1-rmse:514.022
# [140]	validation_0-rmse:428.182	validation_1-rmse:513.998
# [141]	validation_0-rmse:427.998	validation_1-rmse:514.014
# [142]	validation_0-rmse:427.855	validation_1-rmse:513.994
# [143]	validation_0-rmse:427.781	validation_1-rmse:513.916
# [144]	validation_0-rmse:426.985	validation_1-rmse:513.67
# [145]	validation_0-rmse:426.662	validation_1-rmse:513.348
# [146]	validation_0-rmse:426.414	validation_1-rmse:513.359
# [147]	validation_0-rmse:426.102	validation_1-rmse:513.227
# [148]	validation_0-rmse:425.913	validation_1-rmse:513.122
# [149]	validation_0-rmse:425.854	validation_1-rmse:513.122
# [150]	validation_0-rmse:425.762	validation_1-rmse:513.075
# [151]	validation_0-rmse:425.509	validation_1-rmse:513.002
# [152]	validation_0-rmse:425.455	validation_1-rmse:512.901
# [153]	validation_0-rmse:425.383	validation_1-rmse:512.903
# [154]	validation_0-rmse:425.316	validation_1-rmse:512.886
# [155]	validation_0-rmse:425.223	validation_1-rmse:513.121
# [156]	validation_0-rmse:425.151	validation_1-rmse:512.973
# [157]	validation_0-rmse:425.087	validation_1-rmse:512.995
# [158]	validation_0-rmse:425.003	validation_1-rmse:512.957
# [159]	validation_0-rmse:424.878	validation_1-rmse:512.895
# [160]	validation_0-rmse:424.606	validation_1-rmse:512.416
# [161]	validation_0-rmse:424.555	validation_1-rmse:512.395
# [162]	validation_0-rmse:424.458	validation_1-rmse:512.304
# [163]	validation_0-rmse:424.118	validation_1-rmse:512.115
# [164]	validation_0-rmse:423.878	validation_1-rmse:512.01
# [165]	validation_0-rmse:423.82	validation_1-rmse:511.988
# [166]	validation_0-rmse:423.144	validation_1-rmse:511.741
# [167]	validation_0-rmse:423.072	validation_1-rmse:511.749
# [168]	validation_0-rmse:423.024	validation_1-rmse:511.753
# [169]	validation_0-rmse:422.958	validation_1-rmse:511.646
# [170]	validation_0-rmse:422.702	validation_1-rmse:511.594
# [171]	validation_0-rmse:422.634	validation_1-rmse:511.786
# [172]	validation_0-rmse:422.602	validation_1-rmse:511.759
# [173]	validation_0-rmse:422.59	validation_1-rmse:511.708
# [174]	validation_0-rmse:422.384	validation_1-rmse:511.571
# [175]	validation_0-rmse:422.246	validation_1-rmse:511.612
# [176]	validation_0-rmse:421.996	validation_1-rmse:511.627
# [177]	validation_0-rmse:421.941	validation_1-rmse:511.582
# [178]	validation_0-rmse:421.733	validation_1-rmse:511.519
# [179]	validation_0-rmse:421.675	validation_1-rmse:511.525
# [180]	validation_0-rmse:421.544	validation_1-rmse:511.247
# [181]	validation_0-rmse:421.325	validation_1-rmse:510.74
# [182]	validation_0-rmse:421.276	validation_1-rmse:510.656
# [183]	validation_0-rmse:421.249	validation_1-rmse:510.589
# [184]	validation_0-rmse:420.867	validation_1-rmse:510.343
# [185]	validation_0-rmse:420.617	validation_1-rmse:510.256
# [186]	validation_0-rmse:420.563	validation_1-rmse:510.187
# [187]	validation_0-rmse:420.551	validation_1-rmse:510.167
# [188]	validation_0-rmse:420.476	validation_1-rmse:510.145
# [189]	validation_0-rmse:420.249	validation_1-rmse:509.816
# [190]	validation_0-rmse:420.064	validation_1-rmse:509.55
# [191]	validation_0-rmse:420.027	validation_1-rmse:509.441
# [192]	validation_0-rmse:419.84	validation_1-rmse:509.538
# [193]	validation_0-rmse:419.629	validation_1-rmse:509.637
# [194]	validation_0-rmse:419.53	validation_1-rmse:509.835
# [195]	validation_0-rmse:419.475	validation_1-rmse:509.724
# [196]	validation_0-rmse:419.426	validation_1-rmse:509.679
# [197]	validation_0-rmse:419.311	validation_1-rmse:509.54
# [198]	validation_0-rmse:419.059	validation_1-rmse:509.564
# [199]	validation_0-rmse:419.001	validation_1-rmse:509.457
# [200]	validation_0-rmse:418.949	validation_1-rmse:509.615
# [201]	validation_0-rmse:418.864	validation_1-rmse:509.419
# [202]	validation_0-rmse:418.802	validation_1-rmse:509.392
# [203]	validation_0-rmse:418.563	validation_1-rmse:509.26
# [204]	validation_0-rmse:418.397	validation_1-rmse:509.112
# [205]	validation_0-rmse:418.359	validation_1-rmse:509.064
# [206]	validation_0-rmse:418.327	validation_1-rmse:509.009
# [207]	validation_0-rmse:418.156	validation_1-rmse:509.018
# [208]	validation_0-rmse:418.147	validation_1-rmse:508.982
# [209]	validation_0-rmse:418.09	validation_1-rmse:508.984
# [210]	validation_0-rmse:417.958	validation_1-rmse:509.004
# [211]	validation_0-rmse:417.766	validation_1-rmse:509.046
# [212]	validation_0-rmse:417.687	validation_1-rmse:509.05
# [213]	validation_0-rmse:417.523	validation_1-rmse:509.005
# [214]	validation_0-rmse:417.457	validation_1-rmse:508.999
# [215]	validation_0-rmse:417.261	validation_1-rmse:508.9
# [216]	validation_0-rmse:416.879	validation_1-rmse:509.353
# [217]	validation_0-rmse:416.834	validation_1-rmse:509.365
# [218]	validation_0-rmse:416.814	validation_1-rmse:509.361
# [219]	validation_0-rmse:416.761	validation_1-rmse:509.371
# [220]	validation_0-rmse:416.379	validation_1-rmse:509.214
# [221]	validation_0-rmse:416.214	validation_1-rmse:508.94
# [222]	validation_0-rmse:416.157	validation_1-rmse:508.874
# [223]	validation_0-rmse:415.988	validation_1-rmse:508.592
# [224]	validation_0-rmse:415.962	validation_1-rmse:508.545
# [225]	validation_0-rmse:415.841	validation_1-rmse:508.482
# [226]	validation_0-rmse:415.704	validation_1-rmse:508.256
# [227]	validation_0-rmse:415.695	validation_1-rmse:508.231
# [228]	validation_0-rmse:415.669	validation_1-rmse:508.137
# [229]	validation_0-rmse:415.631	validation_1-rmse:508.126
# [230]	validation_0-rmse:415.534	validation_1-rmse:507.914
# [231]	validation_0-rmse:415.372	validation_1-rmse:507.964
# [232]	validation_0-rmse:415.103	validation_1-rmse:508.468
# [233]	validation_0-rmse:414.918	validation_1-rmse:508.469
# [234]	validation_0-rmse:414.872	validation_1-rmse:508.467
# [235]	validation_0-rmse:414.827	validation_1-rmse:508.481
# [236]	validation_0-rmse:414.751	validation_1-rmse:508.379
# [237]	validation_0-rmse:414.479	validation_1-rmse:508.278
# [238]	validation_0-rmse:414.292	validation_1-rmse:507.982
# [239]	validation_0-rmse:414.224	validation_1-rmse:507.887
# [240]	validation_0-rmse:414.07	validation_1-rmse:507.806
# [241]	validation_0-rmse:414.041	validation_1-rmse:507.753
# [242]	validation_0-rmse:414.021	validation_1-rmse:507.708
# [243]	validation_0-rmse:413.862	validation_1-rmse:507.603
# [244]	validation_0-rmse:413.727	validation_1-rmse:507.499
# [245]	validation_0-rmse:413.605	validation_1-rmse:507.359
# [246]	validation_0-rmse:413.578	validation_1-rmse:507.312
# [247]	validation_0-rmse:413.513	validation_1-rmse:507.196
# [248]	validation_0-rmse:413.458	validation_1-rmse:507.131
# [249]	validation_0-rmse:413.419	validation_1-rmse:507.154
# [250]	validation_0-rmse:413.405	validation_1-rmse:507.116
# [251]	validation_0-rmse:413.281	validation_1-rmse:507.006
# [252]	validation_0-rmse:413.243	validation_1-rmse:506.897
# [253]	validation_0-rmse:413.185	validation_1-rmse:506.873
# [254]	validation_0-rmse:413.172	validation_1-rmse:506.87
# [255]	validation_0-rmse:413.009	validation_1-rmse:506.961
# [256]	validation_0-rmse:412.956	validation_1-rmse:507.053
# [257]	validation_0-rmse:412.786	validation_1-rmse:507.087
# [258]	validation_0-rmse:412.737	validation_1-rmse:507.076
# [259]	validation_0-rmse:412.681	validation_1-rmse:506.998
# [260]	validation_0-rmse:412.637	validation_1-rmse:506.979
# [261]	validation_0-rmse:412.595	validation_1-rmse:506.982
# [262]	validation_0-rmse:412.352	validation_1-rmse:507.002
# [263]	validation_0-rmse:412.123	validation_1-rmse:507.001
# [264]	validation_0-rmse:411.877	validation_1-rmse:506.954
# [265]	validation_0-rmse:411.769	validation_1-rmse:506.93
# [266]	validation_0-rmse:411.725	validation_1-rmse:507.065
# [267]	validation_0-rmse:411.685	validation_1-rmse:506.993
# [268]	validation_0-rmse:411.644	validation_1-rmse:506.894
# [269]	validation_0-rmse:411.161	validation_1-rmse:506.875
# [270]	validation_0-rmse:410.956	validation_1-rmse:507.032
# [271]	validation_0-rmse:410.851	validation_1-rmse:507.017
# [272]	validation_0-rmse:410.791	validation_1-rmse:507.136
# [273]	validation_0-rmse:410.754	validation_1-rmse:507.23
# [274]	validation_0-rmse:410.729	validation_1-rmse:507.194
# [275]	validation_0-rmse:410.683	validation_1-rmse:507.166
# [276]	validation_0-rmse:410.549	validation_1-rmse:507.139
# [277]	validation_0-rmse:410.366	validation_1-rmse:507.067
# [278]	validation_0-rmse:410.264	validation_1-rmse:506.998
# [279]	validation_0-rmse:410.131	validation_1-rmse:506.616
# [280]	validation_0-rmse:409.871	validation_1-rmse:506.923
# [281]	validation_0-rmse:409.857	validation_1-rmse:506.915
# [282]	validation_0-rmse:409.554	validation_1-rmse:506.712
# [283]	validation_0-rmse:409.171	validation_1-rmse:506.677
# [284]	validation_0-rmse:408.86	validation_1-rmse:506.674
# [285]	validation_0-rmse:408.735	validation_1-rmse:506.553
# [286]	validation_0-rmse:408.607	validation_1-rmse:506.592
# [287]	validation_0-rmse:408.595	validation_1-rmse:506.578
# [288]	validation_0-rmse:408.58	validation_1-rmse:506.575
# [289]	validation_0-rmse:408.492	validation_1-rmse:506.617
# [290]	validation_0-rmse:408.478	validation_1-rmse:506.583
# [291]	validation_0-rmse:408.332	validation_1-rmse:506.849
# [292]	validation_0-rmse:407.925	validation_1-rmse:506.848
# [293]	validation_0-rmse:407.879	validation_1-rmse:506.776
# [294]	validation_0-rmse:407.794	validation_1-rmse:506.765
# [295]	validation_0-rmse:407.761	validation_1-rmse:506.73
# [296]	validation_0-rmse:407.622	validation_1-rmse:506.85
# [297]	validation_0-rmse:407.574	validation_1-rmse:506.793
# [298]	validation_0-rmse:407.499	validation_1-rmse:506.742
# [299]	validation_0-rmse:407.37	validation_1-rmse:506.61
# [300]	validation_0-rmse:407.097	validation_1-rmse:506.651
# [301]	validation_0-rmse:406.851	validation_1-rmse:506.759
# [302]	validation_0-rmse:406.659	validation_1-rmse:506.787
# [303]	validation_0-rmse:406.37	validation_1-rmse:506.865
# [304]	validation_0-rmse:406.329	validation_1-rmse:506.827
# [305]	validation_0-rmse:406.207	validation_1-rmse:506.998
# [306]	validation_0-rmse:406.076	validation_1-rmse:506.935
# [307]	validation_0-rmse:405.958	validation_1-rmse:506.839
# [308]	validation_0-rmse:405.935	validation_1-rmse:506.816
# [309]	validation_0-rmse:405.769	validation_1-rmse:506.979
# [310]	validation_0-rmse:405.443	validation_1-rmse:507.097
# [311]	validation_0-rmse:405.399	validation_1-rmse:507.109
# [312]	validation_0-rmse:405.113	validation_1-rmse:507.19
# [313]	validation_0-rmse:405.09	validation_1-rmse:507.299
# [314]	validation_0-rmse:405.07	validation_1-rmse:507.187
# [315]	validation_0-rmse:405.056	validation_1-rmse:507.184
# [316]	validation_0-rmse:405.004	validation_1-rmse:507.121
# [317]	validation_0-rmse:404.871	validation_1-rmse:507.113
# [318]	validation_0-rmse:404.776	validation_1-rmse:507.153
# [319]	validation_0-rmse:404.579	validation_1-rmse:507.116
# [320]	validation_0-rmse:404.466	validation_1-rmse:507.16
# [321]	validation_0-rmse:404.441	validation_1-rmse:507.009
# [322]	validation_0-rmse:404.371	validation_1-rmse:507.204
# [323]	validation_0-rmse:404.303	validation_1-rmse:507.243
# [324]	validation_0-rmse:404.243	validation_1-rmse:507.311
# [325]	validation_0-rmse:404.207	validation_1-rmse:507.291
# [326]	validation_0-rmse:404.189	validation_1-rmse:507.282
# [327]	validation_0-rmse:404.068	validation_1-rmse:507.473
# [328]	validation_0-rmse:403.986	validation_1-rmse:507.63
# [329]	validation_0-rmse:403.949	validation_1-rmse:507.644
# [330]	validation_0-rmse:403.9	validation_1-rmse:507.752
# [331]	validation_0-rmse:403.542	validation_1-rmse:507.942
# [332]	validation_0-rmse:403.433	validation_1-rmse:507.961
# [333]	validation_0-rmse:403.329	validation_1-rmse:508.014
# [334]	validation_0-rmse:403.292	validation_1-rmse:508
# [335]	validation_0-rmse:403.101	validation_1-rmse:507.915
# [336]	validation_0-rmse:402.991	validation_1-rmse:507.748
# [337]	validation_0-rmse:402.917	validation_1-rmse:507.73
# [338]	validation_0-rmse:402.883	validation_1-rmse:507.69
# [339]	validation_0-rmse:402.783	validation_1-rmse:507.575
# [340]	validation_0-rmse:402.668	validation_1-rmse:507.862
# [341]	validation_0-rmse:402.648	validation_1-rmse:507.966
# [342]	validation_0-rmse:402.514	validation_1-rmse:507.95
# [343]	validation_0-rmse:402.453	validation_1-rmse:507.934
# [344]	validation_0-rmse:402.371	validation_1-rmse:507.914
# [345]	validation_0-rmse:402.238	validation_1-rmse:508.099
# [346]	validation_0-rmse:402.206	validation_1-rmse:508.125
# [347]	validation_0-rmse:401.873	validation_1-rmse:508.164
# [348]	validation_0-rmse:401.784	validation_1-rmse:508.182
# [349]	validation_0-rmse:401.746	validation_1-rmse:508.109
# [350]	validation_0-rmse:401.681	validation_1-rmse:508.076
# [351]	validation_0-rmse:401.57	validation_1-rmse:507.767
# [352]	validation_0-rmse:401.349	validation_1-rmse:507.808
# [353]	validation_0-rmse:401.264	validation_1-rmse:507.693
# [354]	validation_0-rmse:401.247	validation_1-rmse:507.701
# [355]	validation_0-rmse:401.198	validation_1-rmse:507.497
# [356]	validation_0-rmse:401.121	validation_1-rmse:507.12
# [357]	validation_0-rmse:401.108	validation_1-rmse:507.118
# [358]	validation_0-rmse:401.098	validation_1-rmse:507.117
# [359]	validation_0-rmse:400.995	validation_1-rmse:507.168
# [360]	validation_0-rmse:400.889	validation_1-rmse:507.099
# [361]	validation_0-rmse:400.685	validation_1-rmse:507.094
# [362]	validation_0-rmse:400.527	validation_1-rmse:507.048
# [363]	validation_0-rmse:400.364	validation_1-rmse:507.048
# [364]	validation_0-rmse:400.235	validation_1-rmse:507.008
# [365]	validation_0-rmse:400.152	validation_1-rmse:507.055
# [366]	validation_0-rmse:399.969	validation_1-rmse:507.168
# [367]	validation_0-rmse:399.89	validation_1-rmse:507.426
# [368]	validation_0-rmse:399.877	validation_1-rmse:507.441
# [369]	validation_0-rmse:399.855	validation_1-rmse:507.439
# [370]	validation_0-rmse:399.831	validation_1-rmse:507.394
# [371]	validation_0-rmse:399.748	validation_1-rmse:507.329
# [372]	validation_0-rmse:399.719	validation_1-rmse:507.31
# [373]	validation_0-rmse:399.563	validation_1-rmse:507.165
# [374]	validation_0-rmse:399.553	validation_1-rmse:507.154
# [375]	validation_0-rmse:399.455	validation_1-rmse:507.161
# [376]	validation_0-rmse:399.353	validation_1-rmse:507.253
# [377]	validation_0-rmse:399.255	validation_1-rmse:507.279
# [378]	validation_0-rmse:399.246	validation_1-rmse:507.279
# [379]	validation_0-rmse:399.177	validation_1-rmse:507.274
# [380]	validation_0-rmse:399.104	validation_1-rmse:507.357
# [381]	validation_0-rmse:399.068	validation_1-rmse:507.331
# [382]	validation_0-rmse:398.978	validation_1-rmse:507.274
# [383]	validation_0-rmse:398.932	validation_1-rmse:507.243
# [384]	validation_0-rmse:398.793	validation_1-rmse:507.12
# [385]	validation_0-rmse:398.775	validation_1-rmse:507.104
# Stopping. Best iteration:
# [285]	validation_0-rmse:408.735	validation_1-rmse:506.553
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
xgb.plot_importance(model)

# %%
# Convert processed data into an xgb.DMatrix
dtrain = xgb.DMatrix(X_train, label=y_train)

# %%
def xgb_evaluate(colsample_bytree, gamma, learning_rate, max_delta_step, max_depth_step, min_child_weight, n_estimators, subsample):
    params = {'colsample_bytree': colsample_bytree,
              'eta': 0.1,
              'eval_metric': 'rmse',
              'gamma': gamma,
              'learning_rate': learning_rate,
              'max_delta_step': max_delta_step,
              'max_depth_step': int(max_depth_step),
              'min_child_weight': min_child_weight,
              'n_estimators': n_estimators,
              'seed': 9,
              'subsample': subsample}
    # Use around 1000 boosting rounds in the full model
    cv_result = xgb.cv(params, dtrain, num_boost_round=1000, nfold=3)    
    
    # Bayesian optimization only knows how to maximize, not minimize, so return the negative RMSE
    return -1.0 * cv_result['test-rmse-mean'].iloc[-1]

# %%
xgb_bo = BayesianOptimization(xgb_evaluate, {'colsample_bytree': (0.3, 1),
                                             'gamma': (0, 5),
                                             'learning_rate':(0.01,0.5),
                                             'max_delta_step': (0, 10),
                                             'max_depth_step': (1, 6),
                                             'min_child_weight':(0,5),
                                             'n_estimators':(850, 1200),
                                             'subsample': (0.4, 1.0)})
# Use the expected improvement acquisition function to handle negative numbers
# Optimally needs quite a few more initiation points and number of iterations
xgb_bo.maximize(init_points=6, n_iter=10, acq='ei')
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_de... | max_de... | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -656.7    |  0.3939   |  3.652    |  0.03186  |  3.286    |  4.827    |  2.126    |  948.2    |  0.5072   |
# |  2        | -612.9    |  0.6686   |  1.545    |  0.1852   |  2.46     |  3.244    |  4.304    |  1.17e+03 |  0.7085   |
# |  3        | -615.4    |  0.8191   |  3.267    |  0.1701   |  2.516    |  4.548    |  0.04693  |  906.8    |  0.6628   |
# |  4        | -636.7    |  0.4597   |  3.456    |  0.3487   |  0.6734   |  3.901    |  3.178    |  1.092e+0 |  0.7288   |
# |  5        | -538.9    |  0.9624   |  2.933    |  0.352    |  4.938    |  5.174    |  2.969    |  907.8    |  0.6953   |
# |  6        | -598.0    |  0.8918   |  4.966    |  0.09863  |  6.342    |  4.36     |  0.491    |  1.07e+03 |  0.6463   |
# |  7        | -535.7    |  0.4886   |  1.716    |  0.4958   |  3.729    |  3.312    |  1.647    |  931.6    |  0.8265   |
# |  8        | -577.5    |  0.7445   |  3.264    |  0.1252   |  7.243    |  3.354    |  4.536    |  999.8    |  0.8281   |
# |  9        | -590.8    |  0.5039   |  4.139    |  0.1063   |  6.867    |  5.075    |  4.813    |  965.5    |  0.6791   |
# |  10       | -504.0    |  0.5721   |  4.173    |  0.4986   |  6.147    |  3.831    |  0.4779   |  1.056e+0 |  0.8689   |
# |  11       | -558.2    |  0.8734   |  1.579    |  0.378    |  3.337    |  4.378    |  2.04     |  888.1    |  0.8053   |
# |  12       | -600.1    |  0.7987   |  2.3      |  0.3028   |  2.011    |  1.726    |  1.942    |  936.3    |  0.4958   |
# |  13       | -646.5    |  0.8406   |  2.064    |  0.017    |  9.6      |  3.793    |  3.96     |  1.007e+0 |  0.5299   |
# |  14       | -611.0    |  0.8926   |  0.8216   |  0.06945  |  6.738    |  5.712    |  0.5816   |  949.2    |  0.9498   |
# |  15       | -668.5    |  0.8968   |  1.675    |  0.3943   |  0.1306   |  2.174    |  1.649    |  1.163e+0 |  0.8398   |
# |  16       | -504.4    |  0.7214   |  1.157    |  0.4556   |  6.748    |  1.128    |  3.199    |  1.028e+0 |  0.7595   |
# =========================================================================================================================

# %%
# Write our ensemble method - train 11 models, and weight them all equally by finding the mode of the votes for each well.
# The majority vote for each well is the consensus, which will be our predictions
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import random

random.seed(42)
count = 0
score = 0
scores = 0
prediction_votes=pd.DataFrame()
for num in range(1,2):
    seed = random.randint(1,9000)
    model = xgb.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1, 
                          colsample_bynode=1, colsample_bytree=1, gamma=0,
                          importance_type='gain', learning_rate=0.1, max_delta_step=0,
                          max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
                          n_jobs=-1, nthread=None, objective='reg:squarederror', random_state=0,
                          reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
                          silent=None, subsample=1, verbosity=1).fit(X_train, y_train)
    predictions = model.predict(X_val)
    #score = accuracy_score(y_val, predictions)
    prediction_votes[num] = predictions
    scores += score
    count += 1
    print(score)
    y_pred_proba = model.predict_proba(X_train)[:,1]
    print('Test ROC AUC:', roc_auc_score(y_train, y_pred_proba))

print(f"The average accuracy score using these hyperparams over {count} iterations is {scores/count}")
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-ab11be8caed5> in <module>
#      25     count += 1
#      26     print(score)
# ---> 27     y_pred_proba = model.predict_proba(X_train)[:,1]
#      28     print('Test ROC AUC:', roc_auc_score(y_train, y_pred_proba))
#      29
#
# AttributeError: 'XGBRegressor' object has no attribute 'predict_proba'
