# %%
import numpy as np
import gzip
import pandas as pd
#import pandas_profiling
#!pip install bayesian-optimization
from bayes_opt import BayesianOptimization
import matplotlib as mpb
import pickle

# %%
detailed_listing = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/data/listings.csv.gz'
summary_listing = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/visualisations/listings.csv'

# %%
det_list = pd.read_csv(detailed_listing, compression='gzip', error_bad_lines=False, warn_bad_lines=False)

print(det_list.shape)
det_list.head()
# Out:
# (40125, 106)
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20191205175409   2019-12-06
# 1   344   https://www.airbnb.com/rooms/344  20191205175409   2019-12-06
# 2  2708  https://www.airbnb.com/rooms/2708  20191205175409   2019-12-06
# 3  2732  https://www.airbnb.com/rooms/2732  20191205175409   2019-12-06
# 4  2864  https://www.airbnb.com/rooms/2864  20191205175409   2019-12-07
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1                  Family perfect;Pool;Near Studios!
# 2  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3                              Zen Life at the Beach
# 4  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
# 1  This home is perfect for families; aspiring ch...                none
# 2  Our best memory foam pillows you'll ever sleep...                none
# 3  This is a three story townhouse with the follo...                none
# 4  Centrally located.... Furnished with 42 inch S...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Quiet-yet-close to all the fun in LA! Hollywoo...  ...                t
# 2  We are minutes away from the Mentor Language I...  ...                t
# 3                                                NaN  ...                f
# 4  What makes the neighborhood unique is that the...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02
# 1                                            0               0.19
# 2                                            0               0.33
# 3                                            0               0.19
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
summary_list = pd.read_csv(summary_listing, error_bad_lines=False, warn_bad_lines=False )

print(summary_list.shape)
summary_list.head()
# Out:
# (40125, 16)
#      id                                               name  host_id  \
# 0   109  Amazing bright elegant condo park front *UPGRA...      521
# 1   344                  Family perfect;Pool;Near Studios!      767
# 2  2708  Mirrored Mini-Suite with Fireplace - W. Hollywood     3008
# 3  2732                              Zen Life at the Beach     3041
# 4  2864  *Upscale Professional Home with Beautiful Studio*     3207
#
#         host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0           Paolo         Other Cities   Culver City  33.98209 -118.38494
# 1         Melissa         Other Cities       Burbank  34.16562 -118.33458
# 2           Chas.  City of Los Angeles     Hollywood  34.09768 -118.34602
# 3  Yoga Priestess         Other Cities  Santa Monica  34.00475 -118.48127
# 4       Bernadine         Other Cities    Bellflower  33.87619 -118.11397
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    122              30                  2  2016-05-15
# 1  Entire home/apt    168               2                  8  2019-10-19
# 2     Private room     79              30                 22  2019-08-31
# 3     Private room    140               1                 20  2019-10-03
# 4  Entire home/apt     80               2                  0         NaN
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.02                               1               248
# 1               0.19                               1                62
# 2               0.33                               2               252
# 3               0.19                               2               344
# 4                NaN                               1                 0

# %%
calendar_url = 'http://data.insideairbnb.com/united-states/ca/los-angeles/2019-12-05/data/calendar.csv.gz'

# %%
calendar_df = pd.read_csv(calendar_url, compression='gzip', warn_bad_lines=False, error_bad_lines=False)

print(calendar_df.shape)
calendar_df.head()
# Out:
# (14670849, 7)
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       46858  2019-12-06         f  $300.00        $300.00             3.0
# 1      130915  2019-12-06         f   $90.00         $90.00             1.0
# 2      130915  2019-12-07         f   $90.00         $90.00             1.0
# 3      130915  2019-12-08         f   $90.00         $90.00             1.0
# 4      130915  2019-12-09         f   $90.00         $90.00             1.0
#
#    maximum_nights
# 0            30.0
# 1           730.0
# 2           730.0
# 3           730.0
# 4           730.0

# %%
calendar_df['date'] = pd.to_datetime(calendar_df['date'])
calendar_df['year'] = calendar_df['date'].dt.year
calendar_df['month'] = calendar_df['date'].dt.month
calendar_df['day'] = calendar_df['date'].dt.day
calendar_df = calendar_df.drop(columns='date')
calendar_df['available'] = calendar_df['available'].astype(str)
calendar_df['price'] = calendar_df['price'].replace('$','')
calendar_df['adjusted_price'] = calendar_df['adjusted_price'].str[1:]
# Take care of NAs so this code can run
calendar_df['minimum_nights'].fillna(calendar_df['minimum_nights'].mode()[0], inplace=True)
calendar_df['minimum_nights'] = calendar_df['minimum_nights'].astype(int)
calendar_df['maximum_nights'].fillna(calendar_df['maximum_nights'].mode()[0], inplace=True)
calendar_df['maximum_nights'] = calendar_df['maximum_nights'].astype(int)
calendar_df['price'] = calendar_df['price'].str[1:]
calendar_df.head()
# Out:
#    listing_id available   price adjusted_price  minimum_nights  \
# 0       46858         f  300.00         300.00               3
# 1      130915         f   90.00          90.00               1
# 2      130915         f   90.00          90.00               1
# 3      130915         f   90.00          90.00               1
# 4      130915         f   90.00          90.00               1
#
#    maximum_nights  year  month  day
# 0              30  2019     12    6
# 1             730  2019     12    6
# 2             730  2019     12    7
# 3             730  2019     12    8
# 4             730  2019     12    9

# %%
list(summary_list.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
list(det_list.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
#pandas_profiling.ProfileReport(det_list)

# %%
det_list.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0   109   https://www.airbnb.com/rooms/109  20191205175409   2019-12-06
# 1   344   https://www.airbnb.com/rooms/344  20191205175409   2019-12-06
# 2  2708  https://www.airbnb.com/rooms/2708  20191205175409   2019-12-06
# 3  2732  https://www.airbnb.com/rooms/2732  20191205175409   2019-12-06
# 4  2864  https://www.airbnb.com/rooms/2864  20191205175409   2019-12-07
#
#                                                 name  \
# 0  Amazing bright elegant condo park front *UPGRA...
# 1                  Family perfect;Pool;Near Studios!
# 2  Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3                              Zen Life at the Beach
# 4  *Upscale Professional Home with Beautiful Studio*
#
#                                              summary  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  This home is perfect for families; aspiring ch...
# 2  Our best memory foam pillows you'll ever sleep...
# 3                                                NaN
# 4  Centrally located.... Furnished with 42 inch S...
#
#                                                space  \
# 0  *** Unit upgraded with new bamboo flooring, br...
# 1  Cheerful & comfortable; near studios, amusemen...
# 2  Flickering fireplace.  Blendtec® Designer 625 ...
# 3  This is a three story townhouse with the follo...
# 4  The space is furnished with Thomasville furnit...
#
#                                          description experiences_offered  \
# 0  *** Unit upgraded with new bamboo flooring, br...                none
# 1  This home is perfect for families; aspiring ch...                none
# 2  Our best memory foam pillows you'll ever sleep...                none
# 3  This is a three story townhouse with the follo...                none
# 4  Centrally located.... Furnished with 42 inch S...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Quiet-yet-close to all the fun in LA! Hollywoo...  ...                t
# 2  We are minutes away from the Mentor Language I...  ...                t
# 3                                                NaN  ...                f
# 4  What makes the neighborhood unique is that the...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               2
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.02
# 1                                            0               0.19
# 2                                            0               0.33
# 3                                            0               0.19
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %%
import xgboost as xgb
from sklearn.compose import ColumnTransformer
import category_encoders as ce

# %%
columns = ['price', 'beds', 'bedrooms', 'bathrooms', 'zipcode', 'neighbourhood', 
           'property_type', 'room_type', 'accommodates', 'guests_included',
           'minimum_nights', 'instant_bookable', 'amenities']

train = det_list[columns]

train.head()
# Out:
#      price  beds  bedrooms  bathrooms zipcode neighbourhood property_type  \
# 0  $122.00   3.0       2.0        2.0   90230   Culver City   Condominium
# 1  $168.00   3.0       3.0        1.0   91505       Burbank         House
# 2   $79.00   1.0       1.0        1.5   90046     Hollywood     Apartment
# 3  $140.00   1.0       1.0        1.0   90405  Santa Monica     Apartment
# 4   $80.00   1.0       1.0        1.0   90706    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  minimum_nights  \
# 0  Entire home/apt             6                3              30
# 1  Entire home/apt             6                6               2
# 2     Private room             1                1              30
# 3     Private room             1                1               1
# 4  Entire home/apt             2                1               2
#
#   instant_bookable                                          amenities
# 0                f  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 1                t  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2                t  {Internet,Wifi,"Air conditioning","Wheelchair ...
# 3                f  {Internet,Wifi,Kitchen,Heating,Washer,Dryer,"S...
# 4                f  {TV,"Cable TV",Internet,Wifi,"Air conditioning...

# %%
def create_bool_from_dict(df, seriesdict, feature):
    df[feature] = df[seriesdict].str.contains(feature)
    return df[feature]

amenities_list = ['Cable TV', 'Wifi', 'Kitchen', 'Air conditioning', 'Pool', 'Hot tub', 'grill', 'Washer', 'Dryer']

for x in amenities_list:
    create_bool_from_dict(train, 'amenities', x)

train.head()
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      price  beds  bedrooms  bathrooms zipcode neighbourhood property_type  \
# 0  $122.00   3.0       2.0        2.0   90230   Culver City   Condominium
# 1  $168.00   3.0       3.0        1.0   91505       Burbank         House
# 2   $79.00   1.0       1.0        1.5   90046     Hollywood     Apartment
# 3  $140.00   1.0       1.0        1.0   90405  Santa Monica     Apartment
# 4   $80.00   1.0       1.0        1.0   90706    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  ...  \
# 0  Entire home/apt             6                3  ...
# 1  Entire home/apt             6                6  ...
# 2     Private room             1                1  ...
# 3     Private room             1                1  ...
# 4  Entire home/apt             2                1  ...
#
#                                            amenities Cable TV  Wifi  Kitchen  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...     True  True     True
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...     True  True     True
# 2  {Internet,Wifi,"Air conditioning","Wheelchair ...    False  True     True
# 3  {Internet,Wifi,Kitchen,Heating,Washer,Dryer,"S...    False  True     True
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...     True  True     True
#
#    Air conditioning   Pool  Hot tub  grill  Washer  Dryer
# 0              True   True     True  False    True   True
# 1              True   True    False   True    True   True
# 2              True  False     True  False    True   True
# 3             False  False    False  False    True   True
# 4              True  False     True  False    True   True
#
# [5 rows x 22 columns]

# %%
print(train.isna().sum())
# Out:
# price                  0
# beds                  92
# bedrooms              70
# bathrooms             25
# zipcode              464
# neighbourhood       2225
# property_type          0
# room_type              0
# accommodates           0
# guests_included        0
# minimum_nights         0
# instant_bookable       0
# amenities              0
# Has_AC                 0
# Cable TV               0
# Wifi                   0
# Kitchen                0
# Air conditioning       0
# Pool                   0
# Hot tub                0
# grill                  0
# Washer                 0
# Dryer                  0
# dtype: int64

# %%
train['amenities'].value_counts()
# Out:
# {}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       90
# {TV,"Cable TV",Wifi,Pool,Kitchen,"Free parking on premises","Pets allowed",Gym,"Pets live on this property",Elevator,"Indoor fireplace",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","Fire extinguisher",Essentials,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Lockbox,"Private entrance",Bathtub,"Hot water","Bed linens","Ethernet connection",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware",Oven,Stove,"Patio or balcony",Beachfront}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       35
# {TV,Wifi,"Air conditioning",Kitchen,Heating,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer","Laptop friendly workspace","Hot water"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             30
# {Wifi,Essentials}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        26
# {TV,Internet,Wifi,"Air conditioning",Pool,Kitchen,Gym,Elevator,Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Safety card","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in","Smart lock",Lockbox,"Private living room"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             26
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ..
# {TV,Wifi,"Air conditioning",Kitchen,"Free parking on premises","Pets allowed","Hot tub",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Fire extinguisher","Lock on bedroom door",Hangers,"Hair dryer"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# {TV,"Cable TV",Wifi,"Air conditioning",Kitchen,"Free parking on premises","Free street parking",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Self check-in",Keypad,"Private entrance","Hot water","Bed linens","Extra pillows and blankets","Ethernet connection",Microwave,"Coffee maker",Refrigerator,"Dishes and silverware","Cooking basics",Oven,Stove,"Single level home","Garden or backyard","No stairs or steps to enter","No stairs or steps to enter","No stairs or steps to enter"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free parking on premises",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Hangers,"Hair dryer",Iron,"Private entrance","Hot water"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# {TV,"Cable TV",Wifi,"Air conditioning",Pool,Kitchen,"Free parking on premises","Free street parking","Hot tub","Indoor fireplace",Heating,"Family/kid friendly",Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Private entrance",Bathtub,"High chair","Children’s books and toys","Window guards","Fireplace guards",Crib,"Pack ’n Play/travel crib","Room-darkening shades","Hot water","Body soap","Bath towel","Toilet paper","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"BBQ grill","Patio or balcony","Garden or backyard","Long term stays allowed","Wide hallways","No stairs or steps to enter","Wide entrance for guests","Flat path to guest entrance","Well-lit path to entrance","No stairs or steps to enter","Wide entrance","Extra space around bed","Accessible-height bed","No stairs or steps to enter","Wide doorway to guest bathroom","Accessible-height toilet","No stairs or steps to enter","Wide entryway","Host greets you","Hot water kettle","Heated floors","Smart TV","Mountain view","Jetted tub",Balcony,"Sound system","Gas oven","Fire pit","Breakfast table","Espresso machine","Formal dining area","Pool toys","Private pool","Private hot tub","Double oven",Netflix,"HBO GO","En suite bathroom","Warming drawer","Outdoor seating","Soaking tub","Walk-in shower","Full kitchen","Bedroom comforts","Bathroom essentials"}     1
# {TV,Wifi,"Air conditioning",Kitchen,"Free parking on premises","Free street parking",Heating,Washer,Dryer,"Smoke detector","Carbon monoxide detector","First aid kit","Fire extinguisher",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer","Self check-in","Smart lock",Bathtub,"High chair","Children’s books and toys","Table corner guards","Room-darkening shades","Hot water","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Oven,Stove,"Garden or backyard","Luggage dropoff allowed","Long term stays allowed","Wide entrance for guests","Well-lit path to entrance","Extra space around bed"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: amenities, Length: 37082, dtype: int64

# %%
train['price'] = train['price'].str.replace('$','')
train['price'] = train['price'].str.replace(',','').astype('float')

train['beds'] = train['beds'].fillna(train['beds'].mode()[0])
#train['beds'].fillna(train['beds'].mode()[0], inplace=True)
train['beds'] = train['beds'].astype(int)

train['zipcode'] = train['zipcode'].str.strip()
train['zipcode'] = np.where(train['zipcode'].str.contains('ca', case = False), '', train['zipcode'])
train['zipcode'] = train['zipcode'].str.replace(' ', '')
train['zipcode'] = train['zipcode'].str.replace('139SValenciaAve,Glendora.', '')
train['zipcode'] = train['zipcode'].str[:5]
train['zipcode'] = train['zipcode'].replace('',np.nan)
train['zipcode'] = train['zipcode'].astype(str)

train['instant_bookable'] = np.where(train['instant_bookable'].str.contains('t'), 1, 0)
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
print(train.isna().sum())
# Out:
# price                  0
# beds                  92
# bedrooms              70
# bathrooms             25
# zipcode              464
# neighbourhood       2225
# property_type          0
# room_type              0
# accommodates           0
# guests_included        0
# minimum_nights         0
# instant_bookable       0
# amenities              0
# dtype: int64

# %%
train.dtypes
# Out:
# price                object
# beds                float64
# bedrooms            float64
# bathrooms           float64
# zipcode              object
# neighbourhood        object
# property_type        object
# room_type            object
# accommodates          int64
# guests_included       int64
# minimum_nights        int64
# instant_bookable     object
# amenities            object
# Cable TV               bool
# Wifi                   bool
# Kitchen                bool
# Air conditioning       bool
# Pool                   bool
# Hot tub                bool
# grill                  bool
# Washer                 bool
# Dryer                  bool
# dtype: object

# %%
train.head()
# Out:
#    price  beds  bedrooms  bathrooms zipcode neighbourhood property_type  \
# 0  122.0     3       2.0        2.0   90230   Culver City   Condominium
# 1  168.0     3       3.0        1.0   91505       Burbank         House
# 2   79.0     1       1.0        1.5   90046     Hollywood     Apartment
# 3  140.0     1       1.0        1.0   90405  Santa Monica     Apartment
# 4   80.0     1       1.0        1.0   90706    Bellflower     Apartment
#
#          room_type  accommodates  guests_included  minimum_nights  \
# 0  Entire home/apt             6                3              30
# 1  Entire home/apt             6                6               2
# 2     Private room             1                1              30
# 3     Private room             1                1               1
# 4  Entire home/apt             2                1               2
#
#    instant_bookable
# 0                 0
# 1                 1
# 2                 1
# 3                 0
# 4                 0

# %%
sum(train['neighbourhood'].value_counts() > 5)
# Out:
# 153

# %%
train['room_type'].value_counts()
# Out:
# Entire home/apt    25189
# Private room       13117
# Shared room         1491
# Hotel room           328
# Name: room_type, dtype: int64

# %%
train['bedrooms'].value_counts()
# Out:
# 1.0     23235
# 2.0      6902
# 0.0      4238
# 3.0      3277
# 4.0      1434
# 5.0       627
# 6.0       193
# 7.0        86
# 8.0        30
# 9.0        14
# 10.0        9
# 11.0        6
# 12.0        3
# 21.0        1
# Name: bedrooms, dtype: int64

# %%
train['bathrooms'].value_counts()
# Out:
# 1.0     26690
# 2.0      6102
# 1.5      2601
# 3.0      1282
# 2.5      1224
# 3.5       540
# 4.0       410
# 4.5       299
# 5.0       191
# 5.5       151
# 0.0       111
# 0.5       106
# 6.0       103
# 6.5        65
# 8.0        58
# 7.0        46
# 7.5        28
# 11.0       27
# 8.5        18
# 10.0       13
# 9.0        12
# 9.5         6
# 11.5        4
# 10.5        3
# 13.0        3
# 12.5        2
# 12.0        2
# 13.5        1
# 16.0        1
# 15.0        1
# Name: bathrooms, dtype: int64

# %%
##next will do a linear regression model for a baseline

# %%
# Features we want
categorical_features = ['zipcode','neighbourhood','property_type','room_type']
numeric_features = ['price', 'beds', 'bedrooms', 'bathrooms','accommodates','guests_included','minimum_nights','instant_bookable']
bool_features = ['Cable TV', 'Wifi', 'Kitchen', 'Air conditioning', 'Pool', 'Hot tub', 'grill', 'Washer', 'Dryer']

# %%
#categorical_counts = train.select_dtypes(exclude='number').nunique().sort_values()
categorical_counts = []
categorical_counts.append(train[categorical_features].nunique().sort_values())
high_cardi_cols = []
low_cardi_cols = []
for i in categorical_features:
    if train[i].nunique() > 150:
        high_cardi_cols.append(i)
    else:
        low_cardi_cols.append(i)

# %%
print(categorical_counts, high_cardi_cols, low_cardi_cols)
# Out:
# [room_type          4
# property_type     44
# neighbourhood    165
# zipcode          295
# dtype: int64] ['zipcode', 'neighbourhood'] ['property_type', 'room_type']

# %%
ct = ColumnTransformer([("oe", ce.OrdinalEncoder(), high_cardi_cols),
                        ("ohe", ce.OneHotEncoder(use_cat_names=True), low_cardi_cols)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-53956f6b8bcc> in <module>
# ----> 1 ct = ColumnTransformer([("oe", ce.OrdinalEncoder(), high_cardi_cols),
#       2                         ("ohe", ce.OneHotEncoder(use_cat_names=True), low_cardi_cols)])
#
# NameError: name 'ColumnTransformer' is not defined

# %%
# We'll impute missing values using the median for numeric columns and the most
# common value for string columns.

from sklearn.base import TransformerMixin
class DataFrameImputer(TransformerMixin):
    def fit(self, X, y=None):
        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].median() for c in X],
            index=X.columns)
        return self
    def transform(self, X, y=None):
        return X.fillna(self.fill)

train = DataFrameImputer().fit_transform(train)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
for feature in categorical_features:
    train[feature] = label_encoder.fit_transform(train[feature])

# %%
train.head()
# Out:
#    price  beds  bedrooms  bathrooms  zipcode  neighbourhood  property_type  \
# 0  122.0     3       2.0        2.0       77             29             15
# 1  168.0     3       3.0        1.0      229             19             25
# 2   79.0     1       1.0        1.5       50             59              1
# 3  140.0     1       1.0        1.0      113            118              1
# 4   80.0     1       1.0        1.0      133             14              1
#
#    room_type  accommodates  guests_included  ...  \
# 0          0             6                3  ...
# 1          0             6                6  ...
# 2          2             1                1  ...
# 3          2             1                1  ...
# 4          0             2                1  ...
#
#                                            amenities  Cable TV  Wifi  Kitchen  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...      True  True     True
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...      True  True     True
# 2  {Internet,Wifi,"Air conditioning","Wheelchair ...     False  True     True
# 3  {Internet,Wifi,Kitchen,Heating,Washer,Dryer,"S...     False  True     True
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...      True  True     True
#
#    Air conditioning   Pool  Hot tub  grill  Washer  Dryer
# 0              True   True     True  False    True   True
# 1              True   True    False   True    True   True
# 2              True  False     True  False    True   True
# 3             False  False    False  False    True   True
# 4              True  False     True  False    True   True
#
# [5 rows x 22 columns]

# %%
train['price'].describe()
# Out:
# count    40125.000000
# mean       225.840673
# std        656.723597
# min          0.000000
# 25%         70.000000
# 50%        110.000000
# 75%        189.000000
# max      25000.000000
# Name: price, dtype: float64

# %%
features = numeric_features + categorical_features + bool_features
target = 'price'
train_features = train[features]

# %%
train_labels = train_features['price']
train_features = train_features.drop(columns=['price'])

# %%
X_train = train_features
y_train = train_labels

X_train.shape, y_train.shape
# Out:
# ((40125, 20), (40125,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size = 0.75, 
                                                  test_size = 0.25, random_state=42)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((30093, 20), (10032, 20), (30093,), (10032,))

# %%
from xgboost import XGBRegressor


eval_set = [(X_train, y_train), 
            (X_val, y_val)]

model = XGBRegressor(n_estimators=1000, n_jobs=-1)
model.fit(X_train, y_train, eval_set=eval_set, eval_metric='rmse', 
          early_stopping_rounds=100)
# Out:
# [18:26:22] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:664.634	validation_1-rmse:680.207
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 100 rounds.
# [1]	validation_0-rmse:641.613	validation_1-rmse:660.446
# [2]	validation_0-rmse:622.054	validation_1-rmse:644.062
# [3]	validation_0-rmse:604.029	validation_1-rmse:628.916
# [4]	validation_0-rmse:588.751	validation_1-rmse:616.006
# [5]	validation_0-rmse:575.676	validation_1-rmse:605.547
# [6]	validation_0-rmse:563.57	validation_1-rmse:593.013
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
#
# [104]	validation_0-rmse:432.295	validation_1-rmse:490.826
# [105]	validation_0-rmse:431.737	validation_1-rmse:490.159
# [106]	validation_0-rmse:431.4	validation_1-rmse:489.797
# [107]	validation_0-rmse:430.443	validation_1-rmse:489.689
# [108]	validation_0-rmse:429.775	validation_1-rmse:489.545
# [109]	validation_0-rmse:429.582	validation_1-rmse:489.374
# [110]	validation_0-rmse:429.475	validation_1-rmse:489.362
# [111]	validation_0-rmse:429.002	validation_1-rmse:488.905
# [112]	validation_0-rmse:428.564	validation_1-rmse:488.398
# [113]	validation_0-rmse:427.786	validation_1-rmse:488.377
# [114]	validation_0-rmse:427.761	validation_1-rmse:488.353
# [115]	validation_0-rmse:427.53	validation_1-rmse:488.033
# [116]	validation_0-rmse:427.356	validation_1-rmse:487.958
# [117]	validation_0-rmse:427.248	validation_1-rmse:487.899
# [118]	validation_0-rmse:426.915	validation_1-rmse:487.92
# [119]	validation_0-rmse:425.939	validation_1-rmse:487.844
# [120]	validation_0-rmse:425.462	validation_1-rmse:487.731
# [121]	validation_0-rmse:425.145	validation_1-rmse:487.443
# [122]	validation_0-rmse:425.039	validation_1-rmse:487.43
# [123]	validation_0-rmse:424.671	validation_1-rmse:486.955
# [124]	validation_0-rmse:424.615	validation_1-rmse:486.908
# [125]	validation_0-rmse:424.593	validation_1-rmse:486.86
# [126]	validation_0-rmse:424.184	validation_1-rmse:486.414
# [127]	validation_0-rmse:424.112	validation_1-rmse:486.188
# [128]	validation_0-rmse:423.956	validation_1-rmse:485.912
# [129]	validation_0-rmse:423.327	validation_1-rmse:485.8
# [130]	validation_0-rmse:423.304	validation_1-rmse:485.709
# [131]	validation_0-rmse:423.284	validation_1-rmse:485.723
# [132]	validation_0-rmse:423.103	validation_1-rmse:485.53
# [133]	validation_0-rmse:423.009	validation_1-rmse:485.339
# [134]	validation_0-rmse:422.95	validation_1-rmse:485.26
# [135]	validation_0-rmse:422.935	validation_1-rmse:485.288
# [136]	validation_0-rmse:422.469	validation_1-rmse:484.827
# [137]	validation_0-rmse:422.452	validation_1-rmse:484.756
# [138]	validation_0-rmse:422.315	validation_1-rmse:484.501
# [139]	validation_0-rmse:422.003	validation_1-rmse:484.445
# [140]	validation_0-rmse:421.744	validation_1-rmse:484.249
# [141]	validation_0-rmse:421.552	validation_1-rmse:483.989
# [142]	validation_0-rmse:421.18	validation_1-rmse:483.919
# [143]	validation_0-rmse:420.964	validation_1-rmse:483.878
# [144]	validation_0-rmse:420.862	validation_1-rmse:483.732
# [145]	validation_0-rmse:420.5	validation_1-rmse:483.785
# [146]	validation_0-rmse:420.421	validation_1-rmse:483.749
# [147]	validation_0-rmse:420.339	validation_1-rmse:483.569
# [148]	validation_0-rmse:420.29	validation_1-rmse:483.503
# [149]	validation_0-rmse:420.088	validation_1-rmse:483.382
# [150]	validation_0-rmse:419.911	validation_1-rmse:483.17
# [151]	validation_0-rmse:419.724	validation_1-rmse:483.182
# [152]	validation_0-rmse:419.712	validation_1-rmse:483.176
# [301]	validation_0-rmse:400.352	validation_1-rmse:477.949
# [302]	validation_0-rmse:400.325	validation_1-rmse:477.964
# [303]	validation_0-rmse:400.298	validation_1-rmse:477.953
# [304]	validation_0-rmse:400.08	validation_1-rmse:477.85
# [305]	validation_0-rmse:400.025	validation_1-rmse:477.477
# [306]	validation_0-rmse:399.927	validation_1-rmse:477.472
# [307]	validation_0-rmse:399.771	validation_1-rmse:477.449
# [308]	validation_0-rmse:399.722	validation_1-rmse:477.043
# [309]	validation_0-rmse:399.698	validation_1-rmse:477.089
# [310]	validation_0-rmse:399.569	validation_1-rmse:476.839
# [311]	validation_0-rmse:399.5	validation_1-rmse:476.826
# [312]	validation_0-rmse:399.355	validation_1-rmse:476.763
# [313]	validation_0-rmse:399.16	validation_1-rmse:476.695
# [314]	validation_0-rmse:399.051	validation_1-rmse:476.554
# [315]	validation_0-rmse:398.947	validation_1-rmse:476.394
# [316]	validation_0-rmse:398.678	validation_1-rmse:476.489
# [317]	validation_0-rmse:398.37	validation_1-rmse:476.563
# [318]	validation_0-rmse:398.232	validation_1-rmse:476.451
# [319]	validation_0-rmse:397.986	validation_1-rmse:476.332
# [320]	validation_0-rmse:397.872	validation_1-rmse:476.497
# [321]	validation_0-rmse:397.838	validation_1-rmse:476.522
# [322]	validation_0-rmse:397.627	validation_1-rmse:476.434
# [323]	validation_0-rmse:397.601	validation_1-rmse:476.421
# [324]	validation_0-rmse:397.527	validation_1-rmse:476.437
# [325]	validation_0-rmse:397.307	validation_1-rmse:476.733
# [326]	validation_0-rmse:397.224	validation_1-rmse:476.676
# [327]	validation_0-rmse:397.073	validation_1-rmse:476.719
# [328]	validation_0-rmse:396.974	validation_1-rmse:476.675
# [329]	validation_0-rmse:396.762	validation_1-rmse:476.701
# [330]	validation_0-rmse:396.748	validation_1-rmse:476.701
# [331]	validation_0-rmse:396.55	validation_1-rmse:476.78
# [332]	validation_0-rmse:396.476	validation_1-rmse:476.696
# [333]	validation_0-rmse:396.127	validation_1-rmse:476.51
# [334]	validation_0-rmse:396.063	validation_1-rmse:476.214
# [335]	validation_0-rmse:396.042	validation_1-rmse:476.206
# [336]	validation_0-rmse:396.02	validation_1-rmse:476.212
# [337]	validation_0-rmse:395.999	validation_1-rmse:476.235
# [338]	validation_0-rmse:395.898	validation_1-rmse:476.263
# [339]	validation_0-rmse:395.679	validation_1-rmse:476.365
# [340]	validation_0-rmse:395.664	validation_1-rmse:476.38
# [341]	validation_0-rmse:395.514	validation_1-rmse:476.251
# [342]	validation_0-rmse:395.495	validation_1-rmse:476.232
# [343]	validation_0-rmse:395.43	validation_1-rmse:476.385
# [344]	validation_0-rmse:395.387	validation_1-rmse:476.06
# [345]	validation_0-rmse:395.35	validation_1-rmse:475.726
# [346]	validation_0-rmse:395.327	validation_1-rmse:475.737
# [347]	validation_0-rmse:395.295	validation_1-rmse:475.464
# [348]	validation_0-rmse:395.227	validation_1-rmse:475.414
# [349]	validation_0-rmse:395.085	validation_1-rmse:475.386
# [350]	validation_0-rmse:394.989	validation_1-rmse:475.334
# [351]	validation_0-rmse:394.904	validation_1-rmse:475.347
# [352]	validation_0-rmse:394.774	validation_1-rmse:475.379
# [353]	validation_0-rmse:394.676	validation_1-rmse:475.418
# [354]	validation_0-rmse:394.659	validation_1-rmse:475.43
# [355]	validation_0-rmse:394.543	validation_1-rmse:475.615
# [356]	validation_0-rmse:394.462	validation_1-rmse:475.58
# [357]	validation_0-rmse:394.291	validation_1-rmse:475.492
# [358]	validation_0-rmse:394.216	validation_1-rmse:475.29
# [359]	validation_0-rmse:394.172	validation_1-rmse:475.283
# [360]	validation_0-rmse:393.847	validation_1-rmse:475.432
# [361]	validation_0-rmse:393.754	validation_1-rmse:475.349
# [362]	validation_0-rmse:393.532	validation_1-rmse:475.331
# [363]	validation_0-rmse:393.436	validation_1-rmse:475.345
# [364]	validation_0-rmse:393.246	validation_1-rmse:475.332
# [365]	validation_0-rmse:393.22	validation_1-rmse:475.331
# [366]	validation_0-rmse:393.169	validation_1-rmse:475.204
# [367]	validation_0-rmse:393.132	validation_1-rmse:475.229
# [368]	validation_0-rmse:393.071	validation_1-rmse:475.057
# [369]	validation_0-rmse:392.944	validation_1-rmse:474.924
# [370]	validation_0-rmse:392.66	validation_1-rmse:474.841
# [371]	validation_0-rmse:392.645	validation_1-rmse:474.812
# [372]	validation_0-rmse:392.394	validation_1-rmse:474.844
# [373]	validation_0-rmse:392.363	validation_1-rmse:474.867
# [374]	validation_0-rmse:392.331	validation_1-rmse:474.547
# [375]	validation_0-rmse:392.304	validation_1-rmse:474.326
# [376]	validation_0-rmse:392.301	validation_1-rmse:474.327
# [377]	validation_0-rmse:392.199	validation_1-rmse:474.375
# [378]	validation_0-rmse:392.173	validation_1-rmse:474.416
# [379]	validation_0-rmse:392.162	validation_1-rmse:474.43
# [380]	validation_0-rmse:391.855	validation_1-rmse:474.33
# [381]	validation_0-rmse:391.623	validation_1-rmse:474.364
# [382]	validation_0-rmse:391.61	validation_1-rmse:474.335
# [383]	validation_0-rmse:391.472	validation_1-rmse:474.382
# [384]	validation_0-rmse:391.387	validation_1-rmse:474.311
# [385]	validation_0-rmse:391.369	validation_1-rmse:474.325
# [386]	validation_0-rmse:391.174	validation_1-rmse:474.314
# [387]	validation_0-rmse:391.122	validation_1-rmse:474.148
# [388]	validation_0-rmse:391.091	validation_1-rmse:474.203
# [389]	validation_0-rmse:391.066	validation_1-rmse:474
# [390]	validation_0-rmse:391.043	validation_1-rmse:473.857
# [391]	validation_0-rmse:391.017	validation_1-rmse:473.882
# [392]	validation_0-rmse:390.996	validation_1-rmse:473.653
# [393]	validation_0-rmse:390.978	validation_1-rmse:473.488
# [394]	validation_0-rmse:390.905	validation_1-rmse:473.498
# [395]	validation_0-rmse:390.634	validation_1-rmse:473.452
# [396]	validation_0-rmse:390.604	validation_1-rmse:473.446
# [397]	validation_0-rmse:390.586	validation_1-rmse:473.254
# [398]	validation_0-rmse:390.523	validation_1-rmse:473.212
# [399]	validation_0-rmse:390.475	validation_1-rmse:473.218
# [400]	validation_0-rmse:390.365	validation_1-rmse:473.135
# [401]	validation_0-rmse:390.195	validation_1-rmse:473.181
# [402]	validation_0-rmse:390.091	validation_1-rmse:473.248
# [403]	validation_0-rmse:390.078	validation_1-rmse:473.089
# [404]	validation_0-rmse:390.068	validation_1-rmse:473.116
# [405]	validation_0-rmse:390.023	validation_1-rmse:473.108
# [406]	validation_0-rmse:390.009	validation_1-rmse:473.12
# [407]	validation_0-rmse:389.941	validation_1-rmse:473.223
# [408]	validation_0-rmse:389.868	validation_1-rmse:473.257
# [409]	validation_0-rmse:389.786	validation_1-rmse:473.234
# [410]	validation_0-rmse:389.741	validation_1-rmse:473.227
# [411]	validation_0-rmse:389.546	validation_1-rmse:473.342
# [412]	validation_0-rmse:389.49	validation_1-rmse:473.14
# [413]	validation_0-rmse:389.393	validation_1-rmse:473.068
# [414]	validation_0-rmse:389.357	validation_1-rmse:473.062
# [415]	validation_0-rmse:389.288	validation_1-rmse:472.98
# [416]	validation_0-rmse:389.275	validation_1-rmse:472.97
# [417]	validation_0-rmse:389.194	validation_1-rmse:472.957
# [418]	validation_0-rmse:389.137	validation_1-rmse:472.901
# [419]	validation_0-rmse:388.937	validation_1-rmse:472.827
# [420]	validation_0-rmse:388.924	validation_1-rmse:472.83
# [421]	validation_0-rmse:388.875	validation_1-rmse:472.672
# [422]	validation_0-rmse:388.75	validation_1-rmse:472.656
# [423]	validation_0-rmse:388.635	validation_1-rmse:472.658
# [424]	validation_0-rmse:388.558	validation_1-rmse:472.785
# [425]	validation_0-rmse:388.441	validation_1-rmse:472.409
# [426]	validation_0-rmse:388.43	validation_1-rmse:472.411
# [427]	validation_0-rmse:388.411	validation_1-rmse:472.413
# [428]	validation_0-rmse:388.407	validation_1-rmse:472.413
# [429]	validation_0-rmse:388.353	validation_1-rmse:472.439
# [430]	validation_0-rmse:388.274	validation_1-rmse:472.46
# [431]	validation_0-rmse:388.219	validation_1-rmse:472.433
# [432]	validation_0-rmse:387.69	validation_1-rmse:472.499
# [433]	validation_0-rmse:387.594	validation_1-rmse:472.454
# [434]	validation_0-rmse:387.427	validation_1-rmse:472.481
# [435]	validation_0-rmse:387.419	validation_1-rmse:472.483
# [436]	validation_0-rmse:387.092	validation_1-rmse:472.526
# [437]	validation_0-rmse:386.838	validation_1-rmse:472.526
# [438]	validation_0-rmse:386.791	validation_1-rmse:472.333
# [439]	validation_0-rmse:386.779	validation_1-rmse:472.339
# [440]	validation_0-rmse:386.77	validation_1-rmse:472.336
# [441]	validation_0-rmse:386.754	validation_1-rmse:472.354
# [442]	validation_0-rmse:386.742	validation_1-rmse:472.346
# [443]	validation_0-rmse:386.675	validation_1-rmse:472.3
# [444]	validation_0-rmse:386.444	validation_1-rmse:472.346
# [445]	validation_0-rmse:386.221	validation_1-rmse:472.531
# [446]	validation_0-rmse:385.993	validation_1-rmse:472.538
# [447]	validation_0-rmse:385.927	validation_1-rmse:472.61
# [448]	validation_0-rmse:385.908	validation_1-rmse:472.461
# [449]	validation_0-rmse:385.606	validation_1-rmse:472.448
# [450]	validation_0-rmse:385.595	validation_1-rmse:472.467
# [451]	validation_0-rmse:385.586	validation_1-rmse:472.495
# [452]	validation_0-rmse:385.515	validation_1-rmse:472.481
# [453]	validation_0-rmse:385.448	validation_1-rmse:472.53
# [454]	validation_0-rmse:385.358	validation_1-rmse:472.522
# [455]	validation_0-rmse:385.286	validation_1-rmse:472.433
# [456]	validation_0-rmse:385.06	validation_1-rmse:472.449
# [457]	validation_0-rmse:384.953	validation_1-rmse:472.577
# [458]	validation_0-rmse:384.847	validation_1-rmse:472.495
# [459]	validation_0-rmse:384.838	validation_1-rmse:472.478
# [460]	validation_0-rmse:384.767	validation_1-rmse:472.446
# [461]	validation_0-rmse:384.757	validation_1-rmse:472.442
# [462]	validation_0-rmse:384.716	validation_1-rmse:472.53
# [463]	validation_0-rmse:384.697	validation_1-rmse:472.361
# [464]	validation_0-rmse:384.68	validation_1-rmse:472.205
# [465]	validation_0-rmse:384.672	validation_1-rmse:472.195
# [466]	validation_0-rmse:384.635	validation_1-rmse:472.176
# [467]	validation_0-rmse:384.62	validation_1-rmse:472.032
# [468]	validation_0-rmse:384.419	validation_1-rmse:472.004
# [469]	validation_0-rmse:384.155	validation_1-rmse:472.115
# [470]	validation_0-rmse:383.916	validation_1-rmse:472.117
# [471]	validation_0-rmse:383.799	validation_1-rmse:472.162
# [472]	validation_0-rmse:383.762	validation_1-rmse:472.029
# [473]	validation_0-rmse:383.738	validation_1-rmse:472.099
# [474]	validation_0-rmse:383.736	validation_1-rmse:472.095
# [475]	validation_0-rmse:383.718	validation_1-rmse:472.118
# [476]	validation_0-rmse:383.508	validation_1-rmse:472.124
# [477]	validation_0-rmse:383.402	validation_1-rmse:472.093
# [478]	validation_0-rmse:383.313	validation_1-rmse:472.04
# [479]	validation_0-rmse:383.144	validation_1-rmse:471.746
# [480]	validation_0-rmse:382.942	validation_1-rmse:471.859
# [481]	validation_0-rmse:382.821	validation_1-rmse:471.766
# [482]	validation_0-rmse:382.684	validation_1-rmse:472.02
# [483]	validation_0-rmse:382.602	validation_1-rmse:472.008
# [484]	validation_0-rmse:382.484	validation_1-rmse:471.987
# [485]	validation_0-rmse:382.395	validation_1-rmse:472.023
# [486]	validation_0-rmse:382.321	validation_1-rmse:471.886
# [487]	validation_0-rmse:382.257	validation_1-rmse:471.879
# [488]	validation_0-rmse:382.246	validation_1-rmse:471.882
# [489]	validation_0-rmse:382.18	validation_1-rmse:471.92
# [490]	validation_0-rmse:382.015	validation_1-rmse:472.1
# [491]	validation_0-rmse:381.593	validation_1-rmse:472.353
# [492]	validation_0-rmse:381.392	validation_1-rmse:472.383
# [493]	validation_0-rmse:381.23	validation_1-rmse:472.458
# [494]	validation_0-rmse:381.038	validation_1-rmse:472.46
# [495]	validation_0-rmse:380.868	validation_1-rmse:472.464
# [496]	validation_0-rmse:380.716	validation_1-rmse:472.516
# [497]	validation_0-rmse:380.641	validation_1-rmse:472.674
# [498]	validation_0-rmse:380.509	validation_1-rmse:472.706
# [499]	validation_0-rmse:380.476	validation_1-rmse:472.651
# [500]	validation_0-rmse:380.448	validation_1-rmse:472.656
# [501]	validation_0-rmse:380.441	validation_1-rmse:472.655
# [502]	validation_0-rmse:380.38	validation_1-rmse:472.709
# [503]	validation_0-rmse:380.3	validation_1-rmse:472.519
# [504]	validation_0-rmse:380.298	validation_1-rmse:472.519
# [505]	validation_0-rmse:380.16	validation_1-rmse:472.483
# [506]	validation_0-rmse:380.094	validation_1-rmse:472.534
# [507]	validation_0-rmse:379.982	validation_1-rmse:472.549
# [508]	validation_0-rmse:379.892	validation_1-rmse:472.442
# [509]	validation_0-rmse:379.709	validation_1-rmse:472.507
# [510]	validation_0-rmse:379.663	validation_1-rmse:472.513
# [511]	validation_0-rmse:379.619	validation_1-rmse:472.443
# [512]	validation_0-rmse:379.472	validation_1-rmse:472.534
# [513]	validation_0-rmse:379.419	validation_1-rmse:472.536
# [514]	validation_0-rmse:379.41	validation_1-rmse:472.539
# [515]	validation_0-rmse:379.265	validation_1-rmse:472.698
# [516]	validation_0-rmse:379.205	validation_1-rmse:472.662
# [517]	validation_0-rmse:379.198	validation_1-rmse:472.683
# [518]	validation_0-rmse:379.172	validation_1-rmse:472.634
# [519]	validation_0-rmse:379.089	validation_1-rmse:472.527
# [520]	validation_0-rmse:378.97	validation_1-rmse:472.275
# [521]	validation_0-rmse:378.823	validation_1-rmse:472.249
# [522]	validation_0-rmse:378.796	validation_1-rmse:472.184
# [523]	validation_0-rmse:378.604	validation_1-rmse:472.25
# [524]	validation_0-rmse:378.578	validation_1-rmse:472.255
# [525]	validation_0-rmse:378.553	validation_1-rmse:472.217
# [526]	validation_0-rmse:378.536	validation_1-rmse:472.124
# [527]	validation_0-rmse:378.413	validation_1-rmse:472.181
# [528]	validation_0-rmse:378.314	validation_1-rmse:472.128
# [529]	validation_0-rmse:378.252	validation_1-rmse:472.147
# [530]	validation_0-rmse:378.193	validation_1-rmse:472.235
# [531]	validation_0-rmse:378.141	validation_1-rmse:472.203
# [532]	validation_0-rmse:378.029	validation_1-rmse:472.211
# [533]	validation_0-rmse:378.018	validation_1-rmse:472.219
# [534]	validation_0-rmse:378.01	validation_1-rmse:472.221
# [535]	validation_0-rmse:377.935	validation_1-rmse:472.139
# [536]	validation_0-rmse:377.742	validation_1-rmse:472.101
# [537]	validation_0-rmse:377.62	validation_1-rmse:472.018
# [538]	validation_0-rmse:377.518	validation_1-rmse:472.07
# [539]	validation_0-rmse:377.382	validation_1-rmse:472.074
# [540]	validation_0-rmse:377.265	validation_1-rmse:472.228
# [541]	validation_0-rmse:377.188	validation_1-rmse:472.384
# [542]	validation_0-rmse:377.145	validation_1-rmse:472.401
# [543]	validation_0-rmse:377.061	validation_1-rmse:472.415
# [544]	validation_0-rmse:376.986	validation_1-rmse:472.591
# [545]	validation_0-rmse:376.864	validation_1-rmse:472.685
# [546]	validation_0-rmse:376.762	validation_1-rmse:472.711
# [547]	validation_0-rmse:376.754	validation_1-rmse:472.689
# [548]	validation_0-rmse:376.739	validation_1-rmse:472.684
# [549]	validation_0-rmse:376.682	validation_1-rmse:472.695
# [550]	validation_0-rmse:376.584	validation_1-rmse:472.712
# [551]	validation_0-rmse:376.521	validation_1-rmse:472.879
# [552]	validation_0-rmse:376.511	validation_1-rmse:472.858
# [553]	validation_0-rmse:376.418	validation_1-rmse:472.615
# [554]	validation_0-rmse:376.385	validation_1-rmse:472.604
# [555]	validation_0-rmse:376.362	validation_1-rmse:472.566
# [556]	validation_0-rmse:376.343	validation_1-rmse:472.494
# [557]	validation_0-rmse:376.288	validation_1-rmse:472.497
# [558]	validation_0-rmse:376.104	validation_1-rmse:472.602
# [559]	validation_0-rmse:376.004	validation_1-rmse:472.487
# [560]	validation_0-rmse:375.855	validation_1-rmse:472.528
# [561]	validation_0-rmse:375.847	validation_1-rmse:472.466
# [562]	validation_0-rmse:375.752	validation_1-rmse:472.476
# [563]	validation_0-rmse:375.66	validation_1-rmse:472.52
# [564]	validation_0-rmse:375.525	validation_1-rmse:472.387
# [565]	validation_0-rmse:375.303	validation_1-rmse:472.378
# [566]	validation_0-rmse:375.202	validation_1-rmse:472.416
# [567]	validation_0-rmse:375.122	validation_1-rmse:472.204
# [568]	validation_0-rmse:375.053	validation_1-rmse:472.181
# [569]	validation_0-rmse:374.932	validation_1-rmse:472.276
# [570]	validation_0-rmse:374.766	validation_1-rmse:472.553
# [571]	validation_0-rmse:374.733	validation_1-rmse:472.546
# [572]	validation_0-rmse:374.711	validation_1-rmse:472.6
# [573]	validation_0-rmse:374.703	validation_1-rmse:472.531
# [574]	validation_0-rmse:374.695	validation_1-rmse:472.535
# [575]	validation_0-rmse:374.668	validation_1-rmse:472.53
# [576]	validation_0-rmse:374.632	validation_1-rmse:472.534
# [577]	validation_0-rmse:374.612	validation_1-rmse:472.48
# [578]	validation_0-rmse:374.592	validation_1-rmse:472.544
# [579]	validation_0-rmse:374.584	validation_1-rmse:472.437
# Stopping. Best iteration:
# [479]	validation_0-rmse:383.144	validation_1-rmse:471.746
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
file_name = "xgb_reg.pkl"

# save
pickle.dump(model, open(file_name, "wb"))

# load
xgb_model_loaded = pickle.load(open(file_name, "rb"))

# test
#ind = 1
#test = X_val[ind]
#xgb_model_loaded.predict(test)[0] == xgb_model.predict(test)[0]
# Out:
# [18:52:35] WARNING: d:\build\xgboost\xgboost-0.90.git\src\objective\regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgb.plot_importance(model)

# %%
# Convert processed data into an xgb.DMatrix
dtrain = xgb.DMatrix(X_train, label=y_train)

# %%
def xgb_evaluate(colsample_bytree, gamma, learning_rate, max_delta_step, max_depth_step, min_child_weight, n_estimators, subsample):
    params = {'colsample_bytree': colsample_bytree,
              'eta': 0.1,
              'eval_metric': 'rmse',
              'gamma': gamma,
              'learning_rate': learning_rate,
              'max_delta_step': max_delta_step,
              'max_depth_step': int(max_depth_step),
              'min_child_weight': min_child_weight,
              'n_estimators': n_estimators,
              'seed': 9,
              'subsample': subsample}
    # Use around 1000 boosting rounds in the full model
    cv_result = xgb.cv(params, dtrain, num_boost_round=1000, nfold=3)    
    
    # Bayesian optimization only knows how to maximize, not minimize, so return the negative RMSE
    return -1.0 * cv_result['test-rmse-mean'].iloc[-1]

# %%
xgb_bo = BayesianOptimization(xgb_evaluate, {'colsample_bytree': (0.3, 1),
                                             'gamma': (0, 5),
                                             'learning_rate':(0.01,0.5),
                                             'max_delta_step': (0, 10),
                                             'max_depth_step': (1, 6),
                                             'min_child_weight':(0,5),
                                             'n_estimators':(850, 1200),
                                             'subsample': (0.4, 1.0)})
# Use the expected improvement acquisition function to handle negative numbers
# Optimally needs quite a few more initiation points and number of iterations
xgb_bo.maximize(init_points=6, n_iter=10, acq='ei')
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_de... | max_de... | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# |  1        | -656.7    |  0.3939   |  3.652    |  0.03186  |  3.286    |  4.827    |  2.126    |  948.2    |  0.5072   |
# |  2        | -612.9    |  0.6686   |  1.545    |  0.1852   |  2.46     |  3.244    |  4.304    |  1.17e+03 |  0.7085   |
# |  3        | -615.4    |  0.8191   |  3.267    |  0.1701   |  2.516    |  4.548    |  0.04693  |  906.8    |  0.6628   |
# |  4        | -636.7    |  0.4597   |  3.456    |  0.3487   |  0.6734   |  3.901    |  3.178    |  1.092e+0 |  0.7288   |
# |  5        | -538.9    |  0.9624   |  2.933    |  0.352    |  4.938    |  5.174    |  2.969    |  907.8    |  0.6953   |
# |  6        | -598.0    |  0.8918   |  4.966    |  0.09863  |  6.342    |  4.36     |  0.491    |  1.07e+03 |  0.6463   |
# |  7        | -535.7    |  0.4886   |  1.716    |  0.4958   |  3.729    |  3.312    |  1.647    |  931.6    |  0.8265   |
# |  8        | -577.5    |  0.7445   |  3.264    |  0.1252   |  7.243    |  3.354    |  4.536    |  999.8    |  0.8281   |
# |  9        | -590.8    |  0.5039   |  4.139    |  0.1063   |  6.867    |  5.075    |  4.813    |  965.5    |  0.6791   |
# |  10       | -504.0    |  0.5721   |  4.173    |  0.4986   |  6.147    |  3.831    |  0.4779   |  1.056e+0 |  0.8689   |
# |  11       | -558.2    |  0.8734   |  1.579    |  0.378    |  3.337    |  4.378    |  2.04     |  888.1    |  0.8053   |
# |  12       | -600.1    |  0.7987   |  2.3      |  0.3028   |  2.011    |  1.726    |  1.942    |  936.3    |  0.4958   |
# |  13       | -646.5    |  0.8406   |  2.064    |  0.017    |  9.6      |  3.793    |  3.96     |  1.007e+0 |  0.5299   |
# |  14       | -611.0    |  0.8926   |  0.8216   |  0.06945  |  6.738    |  5.712    |  0.5816   |  949.2    |  0.9498   |
# |  15       | -668.5    |  0.8968   |  1.675    |  0.3943   |  0.1306   |  2.174    |  1.649    |  1.163e+0 |  0.8398   |
# |  16       | -504.4    |  0.7214   |  1.157    |  0.4556   |  6.748    |  1.128    |  3.199    |  1.028e+0 |  0.7595   |
# =========================================================================================================================

# %%
file_name = "xgb_reg_bo.pkl"

# save
pickle.dump(model, open(file_name, "wb"))

# load
xgb_bo_loaded = pickle.load(open(file_name, "rb"))

# %%
# Write our ensemble method - train 11 models, and weight them all equally by finding the mode of the votes for each well.
# The majority vote for each well is the consensus, which will be our predictions
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import random

random.seed(42)
count = 0
score = 0
scores = 0
prediction_votes=pd.DataFrame()
for num in range(1,2):
    seed = random.randint(1,9000)
    model = xgb.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1, 
                          colsample_bynode=1, colsample_bytree=1, gamma=0,
                          importance_type='gain', learning_rate=0.1, max_delta_step=0,
                          max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
                          n_jobs=-1, nthread=None, objective='reg:squarederror', random_state=0,
                          reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
                          silent=None, subsample=1, verbosity=1).fit(X_train, y_train)
    predictions = model.predict(X_val)
    #score = accuracy_score(y_val, predictions)
    prediction_votes[num] = predictions
    scores += score
    count += 1
    print(score)
    y_pred_proba = model.predict_proba(X_train)[:,1]
    print('Test ROC AUC:', roc_auc_score(y_train, y_pred_proba))

print(f"The average accuracy score using these hyperparams over {count} iterations is {scores/count}")
# Out:
# d:\csfiles\lambda\git\airbnb3\airenv\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-ab11be8caed5> in <module>
#      25     count += 1
#      26     print(score)
# ---> 27     y_pred_proba = model.predict_proba(X_train)[:,1]
#      28     print('Test ROC AUC:', roc_auc_score(y_train, y_pred_proba))
#      29
#
# AttributeError: 'XGBRegressor' object has no attribute 'predict_proba'

# %%
opt_model = xgb.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1, 
                          colsample_bynode=1, colsample_bytree=1, gamma=0,
                          importance_type='gain', learning_rate=0.1, max_delta_step=0,
                          max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
                          n_jobs=-1, nthread=None, objective='reg:squarederror', random_state=0,
                          reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
                          silent=None, subsample=1, verbosity=1)
opt_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
xgb.plot_importance(opt_model)

# %%
file_name = "opt_xgb_reg.pkl"

# save
pickle.dump(opt_model, open(file_name, "wb"))

# %%
data = pd.DataFrame.from_dict([{'beds': 1, 'bedrooms': 1.0, 'bathrooms': 1.0, 'accommodates': 2, 'guests_included': 1,
                 'minimum_nights': 2, 'instant_bookable': 0, 'zipcode': 90706, 'neighbourhood': 'Bellflower',
                  'property_type': 'Apartment', 'room_type': 'Entire home/apt', 'Cable TV': True, 'Wifi': True, 'Kitchen': True,
                 'Air conditioning': True, 'Pool': True, 'Hot tub': True, 'grill': True, 'Washer': True, 'Dryer': False
                  }])

def encode_data(df):
    label_encoder = LabelEncoder()
    for feature in categorical_features:
        df[feature] = label_encoder.fit_transform(df[feature])
    return df

data = encode_data(data)

# %%
print(opt_model.predict(data))
# Out:
# [258.783]
